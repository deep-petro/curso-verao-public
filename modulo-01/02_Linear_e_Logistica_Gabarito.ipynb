# %% [markdown]
# # Aprendizado Profundo - UFMG
#
# ## Preâmbulo
#
# O código abaixo consiste dos imports comuns. Além do mais, configuramos as imagens para ficar de um tamanho aceitável e criamos algumas funções auxiliares. No geral, você pode ignorar a próxima célula.

# %%
# -*- coding: utf8

import matplotlib.pyplot as plt
import torch
import numpy as np

plt.rcParams['figure.figsize']  = (18, 10)
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['axes.titlesize']  = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['lines.linewidth'] = 4
torch.set_printoptions(precision=10)

# %%
plt.ion()

plt.style.use('seaborn-colorblind')
plt.rcParams['figure.figsize']  = (12, 8)

# %% [markdown]
# Para testar o resultado dos seus algoritmos vamos usar o módulo testing do numpy.

# %%
from numpy.testing import assert_equal
from numpy.testing import assert_almost_equal
from numpy.testing import assert_array_almost_equal

# %% [markdown]
# ## Regressão Linear e Logística from Scratch
#
# Para brincar um pouco mais com essa diferenciação automatica, presente em frameworks como pytorch e mxnet, nesta aula vamos implementar a regressão linear e logística do zero. Vamos fazer duas versões de cada:
#
# 1. Derivando na mão, não é complicado.
# 2. Derivando com autograd de pytorch

# %% [markdown]
# ## Conjunto de Problemas 1: Mais Derivadas

# %% [markdown]
# Antes de entrar na regressão, vamos brincar um pouco de derivadas dentro de funções. Dado dois números `x` and `y`, implemente a função `log_exp` que retorna:
#
# $$-\log\left(\frac{e^x}{e^x+e^y}\right)$$

# %%
def log_exp(x, y):
    return (-torch.log(torch.exp(x) / (torch.exp(x) + torch.exp(y)))).double()

# %% [markdown]
# 1. Abaixo vamos testar o seu código com algumas entradas simples.

# %%
x, y = torch.tensor([2.0]), torch.tensor([3.0])
z = log_exp(x, y)
z
# Out:
# tensor([1.3132617474], dtype=torch.float64)

# %%
# Teste. Não apague
assert_almost_equal(1.31326175, z.numpy())

# %% [markdown]
# 2. A função a seguir computa $\partial z/\partial x$ e $\partial z/\partial y$ usando `autograd`.

# %%
# O argumento funcao_forward é uma função python. Será a sua log_exp.
# A ideia aqui é deixar claro a ideia de forward e backward propagation, depois
# de avaliar a função chamamos backward e temos as derivadas.
def grad(funcao_forward, x, y):
    x.requires_grad_(True)
    y.requires_grad_(True)
    z = funcao_forward(x, y)
    z.backward()
    return x.grad, y.grad

# %% [markdown]
# Testando

# %%
x, y = torch.tensor([2.0], dtype = torch.double) ,torch.tensor([3.0], dtype = torch.double)
dx, dy = grad(log_exp, x, y)

# %%
assert_almost_equal(-0.7310586, dx.numpy())
assert_almost_equal(0.7310586, dy.numpy())

# %% [markdown]
# 4. Agora teste com números maiores, algum problema?

# %%
x, y = torch.tensor([400.0]).double() ,torch.tensor([800.0]).double()
grad(log_exp, x, y)
# Out:
# (tensor([nan], dtype=torch.float64), tensor([nan], dtype=torch.float64))

# %% [markdown]
# 5. Pense um pouco sobre o motivo do erro acima. Usando as propriedade de logaritmos, é possível fazer uma função mais estável. Abaixo segue a implementação da mesma. O problema aqui é que o exponencial "explode" quando x ou y são muito grandes. Este [link](http://www.wolframalpha.com/input/?i=log[e%5Ex+%2F+[e%5Ex+%2B+e%5Ey]]) pode ajudar.

# %%
x, y = torch.tensor([400.0], dtype = torch.double) ,torch.tensor([800.0], dtype = torch.double)
def stable_log_exp(x, y):
    return torch.log(1+torch.exp(y-x))

dx, dy = grad(stable_log_exp, x, y)

# %%
stable_log_exp(x, y)
# Out:
# tensor([400.], dtype=torch.float64, grad_fn=<LogBackward>)

# %%
# Teste. Não apague
assert_equal(-1, dx.numpy())
assert_equal(1, dy.numpy())

# %% [markdown]
# O exemplo acima mostra um pouco de problemas de estabilidade númerica. Às vezes é melhor usar versões alternativas de funções. Isto vai ocorrer quando você ver vários nans na sua frente :-) Claro, estamos assumindo que existe uma outra função equivalente que é mais estável para o computador.

# %% [markdown]
# ## Conjunto de Problemas 2: Regressão Linear
#
# Agora, vamos explorar uma regressão linear. Embora não vamos fazer uso da logexp acima, a ideia de derivar parcialmente dentro de funções pode nos ajudar. Lembrando da regressão linear, inicialmente temos um conjunto observações representadas como tuplas $(\mathbf{x}_i, y_i)$. Aqui, $\mathbf{x}_i$ é um vetor de atributos. Vamo forçar $\mathbf{x}_{i0} = 1$, capturando assim o intercepto. Além do mais, $\mathbf{x}_{ij}$ quando $j\neq 0$, são os outros atributos de entrada. $y_i$ um valor real representando uma resposta. Nossa regressão visa capturar:
#
# $$y_i = 1 + \theta_1 x_{i1} + \theta_2 x_{i2} + \cdots + \theta_k x_{if}$$
#
# Lembrando da regressão linear multivariada, podemos representar as equações como uma multiplicação de uma matriz com um vetor
#
# ![](./figs/linear.png)
#
# 7. Crie uma função de previsao. A mesma recebe uma matrix $\mathbf{X}$ e um vetor de parâmetros $\theta$. Sua função deve retornar um vetor de previsões para cada linha de $\mathbf{X}$. Não use nenhum laço!!

# %%
def previsao(X, theta):
    return torch.matmul(X, theta.float())

# %% [markdown]
# **Erros quadrados**. Para aprender os parâmetros ótimos da regressão linear, precisamos fazer uso de um modelo de erros quadrados. Em particular nosso objetico é aprender os parâmetros que minimizam a função:
#
# $$L(\mathbf{\theta}) = n^{-1} \sum_i ({\hat{y}_i - y_i})^2$$
#
# Onde $\hat{y}_i$ é uma previsão (vêm da sua função python acima). $y_i$ é o valor real dos dados.
#
# 8. Implemente uma função para a média dos os erros quadrados.

# %%
def media_erros_quadrados(X, theta, y):
    pred = previsao(X, theta) 
    return torch.pow(pred- y, 2).mean()

# %% [markdown]
# 9. Agora, crie uma função que deriva o erro acima. A função deve usar o autograd do pytorch (função backward). Lembre-se que temos um vetor de parâmetros $\theta$. Por sorte, você pode fazer derivadas de tais vetores também.

# %%
def derivada_torch(X, theta, y): #Lembre que o theta passado devera ser uma variavel com requires_grad == True
    e = media_erros_quadrados(X, theta, y)
    e.backward()
    return theta.grad

# %% [markdown]
# 10. A versão a seguir não usa autograd. As derivadas são implementadas do zero.

# %%
def derivada_navera(X, theta, y):
    return ((torch.matmul(X, theta) - y) * X.T).mean(axis=1)

# %% [markdown]
# 11. Por fim, otimize sua função usando o algoritmo de gradiente descendente abaixo.

# %%
def gd(d_fun, loss_fun, X, y, lambda_=0.01, tol=0.00001, max_iter=10000):
    '''
    Executa Gradiente Descendente. Aqui:
    
    Parâmetros
    ----------
    d_fun : é uma função de derivadas
    loss_fun : é uma função de perda
    X : é um vetor de fatores explanatórios.
        Copie seu código de intercepto da primeira aula.
        para adicionar o intercepto em X.
    y : é a resposta
    lambda : é a taxa de aprendizado
    tol : é a tolerância, define quando o algoritmo vai parar.
    max_ter : é a segunda forma de parada, mesmo sem convergir
              paramos depois de max_iter iterações.
    '''
    theta = torch.randn(X.shape[1])
    theta.requires_grad_(True)
    
    print('Iter {}; theta = '.format(0), theta)
    
    old_err_sq = np.inf
    i = 0
    while True:
        # Computar as derivadas
                
        theta.requires_grad_(True)  #Necessario pois ao final, theta recebe o theta novo, que não tem requires_grad == True
        grad = d_fun(X,theta,y)

        # Atualizar
        with torch.no_grad(): 
            theta_novo = theta - lambda_ * grad
        
        #Parar quando o erro convergir
        err_sq = loss_fun(X, theta, y)
        if torch.abs(old_err_sq - err_sq) <= tol:
            break
        
         #Atualizar parâmetros e erro
        theta = theta_novo
        old_err_sq = err_sq
        
        # Informação de debug
        print('Iter {}; theta = '.format(i+1), theta)
        i += 1
        if i == max_iter:
            break
        
    return theta

# %%
# Para testes, não apague!!!
X = torch.zeros(1000, 2)
X[:, 0] = 1.0
X[:, 1] = torch.randn(1000)

theta_0_real = 7.0
theta_1_real = 9.0
y = theta_0_real + theta_1_real * X[:, 1]

# %%
# Testando com derivada autograd. Sua função deve retornar algo perto de 7 e 9
theta = gd(derivada_torch, media_erros_quadrados, X, y)
# Out:
# Iter 0; theta =  tensor([-0.8818951249,  0.3904314041], requires_grad=True)
# Iter 1; theta =  tensor([-0.7271322012,  0.5481043458])
# Iter 2; theta =  tensor([-0.5754118562,  0.7028932571])
# Iter 3; theta =  tensor([-0.4266742468,  0.8548505306])
# Iter 4; theta =  tensor([-0.2808606029,  1.0040282011])
# Iter 5; theta =  tensor([-0.1379134059,  1.1504770517])
# Iter 6; theta =  tensor([0.0022237003, 1.2942466736])
# Iter 7; theta =  tensor([0.1396060884, 1.4353863001])
# Iter 8; theta =  tensor([0.2742879391, 1.5739439726])
# Iter 9; theta =  tensor([0.4063223600, 1.7099666595])
# Iter 10; theta =  tensor([0.5357615948, 1.8435007334])
# Iter 11; theta =  tensor([0.6626566648, 1.9745917320])
# Iter 12; theta =  tensor([0.7870575190, 2.1032843590])
# Iter 13; theta =  tensor([0.9090133905, 2.2296223640])
# Iter 14; theta =  tensor([1.0285723209, 2.3536486626])
# Iter 15; theta =  tensor([1.1457815170, 2.4754056931])
# Iter 16; theta =  tensor([1.2606872320, 2.5949347019])
# Iter 17; theta =  tensor([1.3733346462, 2.7122766972])
# Iter 18; theta =  tensor([1.4837683439, 2.8274712563])
# Iter 19; theta =  tensor([1.5920318365, 2.9405579567])
# Iter 20; theta =  tensor([1.6981676817, 3.0515751839])
# Iter 21; theta =  tensor([1.8022179604, 3.1605608463])
# Iter 22; theta =  tensor([1.9042235613, 3.2675518990])
# Iter 23; theta =  tensor([2.0042247772, 3.3725848198])
# Iter 24; theta =  tensor([2.1022613049, 3.4756956100])
# Iter 25; theta =  tensor([2.1983714104, 3.5769193172])
# Iter 26; theta =  tensor([2.2925930023, 3.6762902737])
# Iter 27; theta =  tensor([2.3849635124, 3.7738425732])
# Iter 28; theta =  tensor([2.4755191803, 3.8696093559])
# Iter 29; theta =  tensor([2.5642957687, 3.9636232853])
# Iter 30; theta =  tensor([2.6513280869, 4.0559163094])
# Iter 31; theta =  tensor([2.7366504669, 4.1465201378])
# Iter 32; theta =  tensor([2.8202967644, 4.2354655266])
# Iter 33; theta =  tensor([2.9022998810, 4.3227825165])
# Iter 34; theta =  tensor([2.9826920033, 4.4085011482])
# Iter 35; theta =  tensor([3.0615050793, 4.4926505089])
# Iter 36; theta =  tensor([3.1387698650, 4.5752592087])
# Iter 37; theta =  tensor([3.2145168781, 4.6563558578])
# Iter 38; theta =  tensor([3.2887761593, 4.7359676361])
# Iter 39; theta =  tensor([3.3615767956, 4.8141222000])
# Iter 40; theta =  tensor([3.4329473972, 4.8908457756])
# Iter 41; theta =  tensor([3.5029163361, 4.9661645889])
# Iter 42; theta =  tensor([3.5715110302, 5.0401043892])
# Iter 43; theta =  tensor([3.6387584209, 5.1126904488])
# Iter 44; theta =  tensor([3.7046852112, 5.1839475632])
# Iter 45; theta =  tensor([3.7693171501, 5.2538995743])
# Iter 46; theta =  tensor([3.8326797485, 5.3225708008])
# Iter 47; theta =  tensor([3.8947980404, 5.3899846077])
# Iter 48; theta =  tensor([3.9556965828, 5.4561638832])
# Iter 49; theta =  tensor([4.0153994560, 5.5211315155])
# Iter 50; theta =  tensor([4.0739297867, 5.5849094391])
# Iter 51; theta =  tensor([4.1313109398, 5.6475191116])
# Iter 52; theta =  tensor([4.1875653267, 5.7089824677])
# Iter 53; theta =  tensor([4.2427148819, 5.7693200111])
# Iter 54; theta =  tensor([4.2967820168, 5.8285527229])
# Iter 55; theta =  tensor([4.3497872353, 5.8867001534])
# Iter 56; theta =  tensor([4.4017519951, 5.9437828064])
# Iter 57; theta =  tensor([4.4526963234, 5.9998202324])
# Iter 58; theta =  tensor([4.5026407242, 6.0548310280])
# Iter 59; theta =  tensor([4.5516042709, 6.1088342667])
# Iter 60; theta =  tensor([4.5996069908, 6.1618485451])
# Iter 61; theta =  tensor([4.6466670036, 6.2138915062])
# Iter 62; theta =  tensor([4.6928033829, 6.2649812698])
# Iter 63; theta =  tensor([4.7380342484, 6.3151350021])
# Iter 64; theta =  tensor([4.7823767662, 6.3643703461])
# Iter 65; theta =  tensor([4.8258490562, 6.4127035141])
# Iter 66; theta =  tensor([4.8684682846, 6.4601511955])
# Iter 67; theta =  tensor([4.9102506638, 6.5067296028])
# Iter 68; theta =  tensor([4.9512128830, 6.5524549484])
# Iter 69; theta =  tensor([4.9913711548, 6.5973424911])
# Iter 70; theta =  tensor([5.0307412148, 6.6414079666])
# Iter 71; theta =  tensor([5.0693387985, 6.6846661568])
# Iter 72; theta =  tensor([5.1071786880, 6.7271313667])
# Iter 73; theta =  tensor([5.1442761421, 6.7688188553])
# Iter 74; theta =  tensor([5.1806454659, 6.8097424507])
# Iter 75; theta =  tensor([5.2163009644, 6.8499159813])
# Iter 76; theta =  tensor([5.2512569427, 6.8893537521])
# Iter 77; theta =  tensor([5.2855272293, 6.9280686378])
# Iter 78; theta =  tensor([5.3191246986, 6.9660739899])
# Iter 79; theta =  tensor([5.3520631790, 7.0033831596])
# Iter 80; theta =  tensor([5.3843550682, 7.0400085449])
# Iter 81; theta =  tensor([5.4160132408, 7.0759630203])
# Iter 82; theta =  tensor([5.4470505714, 7.1112585068])
# Iter 83; theta =  tensor([5.4774789810, 7.1459069252])
# Iter 84; theta =  tensor([5.5073103905, 7.1799206734])
# Iter 85; theta =  tensor([5.5365562439, 7.2133111954])
# Iter 86; theta =  tensor([5.5652284622, 7.2460894585])
# Iter 87; theta =  tensor([5.5933380127, 7.2782669067])
# Iter 88; theta =  tensor([5.6208963394, 7.3098549843])
# Iter 89; theta =  tensor([5.6479139328, 7.3408637047])
# Iter 90; theta =  tensor([5.6744017601, 7.3713045120])
# Iter 91; theta =  tensor([5.7003698349, 7.4011869431])
# Iter 92; theta =  tensor([5.7258286476, 7.4305219650])
# Iter 93; theta =  tensor([5.7507882118, 7.4593191147])
# Iter 94; theta =  tensor([5.7752580643, 7.4875884056])
# Iter 95; theta =  tensor([5.7992477417, 7.5153393745])
# Iter 96; theta =  tensor([5.8227667809, 7.5425820351])
# Iter 97; theta =  tensor([5.8458247185, 7.5693249702])
# Iter 98; theta =  tensor([5.8684306145, 7.5955777168])
# Iter 99; theta =  tensor([5.8905930519, 7.6213493347])
# Iter 100; theta =  tensor([5.9123206139, 7.6466484070])
# Iter 101; theta =  tensor([5.9336223602, 7.6714839935])
# Iter 102; theta =  tensor([5.9545063972, 7.6958642006])
# Iter 103; theta =  tensor([5.9749808311, 7.7197971344])
# Iter 104; theta =  tensor([5.9950537682, 7.7432913780])
# Iter 105; theta =  tensor([6.0147328377, 7.7663550377])
# Iter 106; theta =  tensor([6.0340261459, 7.7889957428])
# Iter 107; theta =  tensor([6.0529413223, 7.8112211227])
# Iter 108; theta =  tensor([6.0714855194, 7.8330392838])
# Iter 109; theta =  tensor([6.0896663666, 7.8544573784])
# Iter 110; theta =  tensor([6.1074905396, 7.8754825592])
# Iter 111; theta =  tensor([6.1249651909, 7.8961224556])
# Iter 112; theta =  tensor([6.1420974731, 7.9163837433])
# Iter 113; theta =  tensor([6.1588935852, 7.9362735748])
# Iter 114; theta =  tensor([6.1753606796, 7.9557986259])
# Iter 115; theta =  tensor([6.1915049553, 7.9749655724])
# Iter 116; theta =  tensor([6.2073326111, 7.9937810898])
# Iter 117; theta =  tensor([6.2228498459, 8.0122518539])
# Iter 118; theta =  tensor([6.2380628586, 8.0303840637])
# Iter 119; theta =  tensor([6.2529778481, 8.0481834412])
# Iter 120; theta =  tensor([6.2676005363, 8.0656566620])
# Iter 121; theta =  tensor([6.2819366455, 8.0828094482])
# Iter 122; theta =  tensor([6.2959914207, 8.0996475220])
# Iter 123; theta =  tensor([6.3097710609, 8.1161766052])
# Iter 124; theta =  tensor([6.3232803345, 8.1324024200])
# Iter 125; theta =  tensor([6.3365249634, 8.1483306885])
# Iter 126; theta =  tensor([6.3495101929, 8.1639671326])
# Iter 127; theta =  tensor([6.3622407913, 8.1793165207])
# Iter 128; theta =  tensor([6.3747220039, 8.1943845749])
# Iter 129; theta =  tensor([6.3869585991, 8.2091760635])
# Iter 130; theta =  tensor([6.3989553452, 8.2236957550])
# Iter 131; theta =  tensor([6.4107170105, 8.2379493713])
# Iter 132; theta =  tensor([6.4222483635, 8.2519416809])
# Iter 133; theta =  tensor([6.4335536957, 8.2656774521])
# Iter 134; theta =  tensor([6.4446372986, 8.2791604996])
# Iter 135; theta =  tensor([6.4555039406, 8.2923965454])
# Iter 136; theta =  tensor([6.4661574364, 8.3053894043])
# Iter 137; theta =  tensor([6.4766025543, 8.3181447983])
# Iter 138; theta =  tensor([6.4868426323, 8.3306655884])
# Iter 139; theta =  tensor([6.4968824387, 8.3429565430])
# Iter 140; theta =  tensor([6.5067253113, 8.3550224304])
# Iter 141; theta =  tensor([6.5163755417, 8.3668670654])
# Iter 142; theta =  tensor([6.5258364677, 8.3784942627])
# Iter 143; theta =  tensor([6.5351123810, 8.3899078369])
# Iter 144; theta =  tensor([6.5442066193, 8.4011125565])
# Iter 145; theta =  tensor([6.5531225204, 8.4121112823])
# Iter 146; theta =  tensor([6.5618638992, 8.4229078293])
# Iter 147; theta =  tensor([6.5704340935, 8.4335069656])
# Iter 148; theta =  tensor([6.5788364410, 8.4439115524])
# Iter 149; theta =  tensor([6.5870738029, 8.4541254044])
# Iter 150; theta =  tensor([6.5951499939, 8.4641513824])
# Iter 151; theta =  tensor([6.6030678749, 8.4739933014])
# Iter 152; theta =  tensor([6.6108307838, 8.4836549759])
# Iter 153; theta =  tensor([6.6184415817, 8.4931392670])
# Iter 154; theta =  tensor([6.6259036064, 8.5024490356])
# Iter 155; theta =  tensor([6.6332192421, 8.5115880966])
# Iter 156; theta =  tensor([6.6403918266, 8.5205593109])
# Iter 157; theta =  tensor([6.6474237442, 8.5293664932])
# Iter 158; theta =  tensor([6.6543183327, 8.5380115509])
# Iter 159; theta =  tensor([6.6610774994, 8.5464982986])
# Iter 160; theta =  tensor([6.6677045822, 8.5548286438])
# Iter 161; theta =  tensor([6.6742019653, 8.5630064011])
# Iter 162; theta =  tensor([6.6805720329, 8.5710344315])
# Iter 163; theta =  tensor([6.6868171692, 8.5789146423])
# Iter 164; theta =  tensor([6.6929402351, 8.5866508484])
# Iter 165; theta =  tensor([6.6989436150, 8.5942449570])
# Iter 166; theta =  tensor([6.7048292160, 8.6016988754])
# Iter 167; theta =  tensor([6.7105994225, 8.6090164185])
# Iter 168; theta =  tensor([6.7162570953, 8.6161994934])
# Iter 169; theta =  tensor([6.7218036652, 8.6232509613])
# Iter 170; theta =  tensor([6.7272419930, 8.6301727295])
# Iter 171; theta =  tensor([6.7325735092, 8.6369676590])
# Iter 172; theta =  tensor([6.7378005981, 8.6436376572])
# Iter 173; theta =  tensor([6.7429256439, 8.6501855850])
# Iter 174; theta =  tensor([6.7479505539, 8.6566133499])
# Iter 175; theta =  tensor([6.7528767586, 8.6629228592])
# Iter 176; theta =  tensor([6.7577066422, 8.6691169739])
# Iter 177; theta =  tensor([6.7624421120, 8.6751966476])
# Iter 178; theta =  tensor([6.7670845985, 8.6811647415])
# Iter 179; theta =  tensor([6.7716364861, 8.6870231628])
# Iter 180; theta =  tensor([6.7760992050, 8.6927747726])
# Iter 181; theta =  tensor([6.7804746628, 8.6984205246])
# Iter 182; theta =  tensor([6.7847642899, 8.7039623260])
# Iter 183; theta =  tensor([6.7889699936, 8.7094020844])
# Iter 184; theta =  tensor([6.7930936813, 8.7147426605])
# Iter 185; theta =  tensor([6.7971367836, 8.7199850082])
# Iter 186; theta =  tensor([6.8011007309, 8.7251310349])
# Iter 187; theta =  tensor([6.8049869537, 8.7301826477])
# Iter 188; theta =  tensor([6.8087968826, 8.7351417542])
# Iter 189; theta =  tensor([6.8125324249, 8.7400093079])
# Iter 190; theta =  tensor([6.8161950111, 8.7447872162])
# Iter 191; theta =  tensor([6.8197860718, 8.7494773865])
# Iter 192; theta =  tensor([6.8233065605, 8.7540817261])
# Iter 193; theta =  tensor([6.8267583847, 8.7586011887])
# Iter 194; theta =  tensor([6.8301424980, 8.7630376816])
# Iter 195; theta =  tensor([6.8334603310, 8.7673931122])
# Iter 196; theta =  tensor([6.8367133141, 8.7716684341])
# Iter 197; theta =  tensor([6.8399028778, 8.7758655548])
# Iter 198; theta =  tensor([6.8430299759, 8.7799854279])
# Iter 199; theta =  tensor([6.8460960388, 8.7840299606])
# Iter 200; theta =  tensor([6.8491020203, 8.7880001068])
# Iter 201; theta =  tensor([6.8520493507, 8.7918968201])
# Iter 202; theta =  tensor([6.8549389839, 8.7957220078])
# Iter 203; theta =  tensor([6.8577718735, 8.7994766235])
# Iter 204; theta =  tensor([6.8605494499, 8.8031625748])
# Iter 205; theta =  tensor([6.8632726669, 8.8067808151])
# Iter 206; theta =  tensor([6.8659424782, 8.8103332520])
# Iter 207; theta =  tensor([6.8685603142, 8.8138198853])
# Iter 208; theta =  tensor([6.8711271286, 8.8172426224])
# Iter 209; theta =  tensor([6.8736433983, 8.8206024170])
# Iter 210; theta =  tensor([6.8761105537, 8.8239002228])
# Iter 211; theta =  tensor([6.8785295486, 8.8271379471])
# Iter 212; theta =  tensor([6.8809013367, 8.8303155899])
# Iter 213; theta =  tensor([6.8832268715, 8.8334350586])
# Iter 214; theta =  tensor([6.8855066299, 8.8364973068])
# Iter 215; theta =  tensor([6.8877420425, 8.8395032883])
# Iter 216; theta =  tensor([6.8899335861, 8.8424539566])
# Iter 217; theta =  tensor([6.8920822144, 8.8453502655])
# Iter 218; theta =  tensor([6.8941888809, 8.8481941223])
# Iter 219; theta =  tensor([6.8962545395, 8.8509855270])
# Iter 220; theta =  tensor([6.8982796669, 8.8537254333])
# Iter 221; theta =  tensor([6.9002652168, 8.8564147949])
# Iter 222; theta =  tensor([6.9022121429, 8.8590545654])
# Iter 223; theta =  tensor([6.9041209221, 8.8616466522])
# Iter 224; theta =  tensor([6.9059925079, 8.8641910553])
# Iter 225; theta =  tensor([6.9078273773, 8.8666887283])
# Iter 226; theta =  tensor([6.9096264839, 8.8691396713])
# Iter 227; theta =  tensor([6.9113903046, 8.8715457916])
# Iter 228; theta =  tensor([6.9131197929, 8.8739080429])
# Iter 229; theta =  tensor([6.9148154259, 8.8762264252])
# Iter 230; theta =  tensor([6.9164776802, 8.8785028458])
# Iter 231; theta =  tensor([6.9181075096, 8.8807373047])
# Iter 232; theta =  tensor([6.9197053909, 8.8829307556])
# Iter 233; theta =  tensor([6.9212722778, 8.8850841522])
# Iter 234; theta =  tensor([6.9228086472, 8.8871974945])
# Iter 235; theta =  tensor([6.9243149757, 8.8892717361])
# Iter 236; theta =  tensor([6.9257917404, 8.8913078308])
# Iter 237; theta =  tensor([6.9272394180, 8.8933067322])
# Iter 238; theta =  tensor([6.9286589622, 8.8952693939])
# Iter 239; theta =  tensor([6.9300508499, 8.8971958160])
# Iter 240; theta =  tensor([6.9314155579, 8.8990869522])
# Iter 241; theta =  tensor([6.9327535629, 8.9009428024])
# Iter 242; theta =  tensor([6.9340653419, 8.9027643204])
# Iter 243; theta =  tensor([6.9353513718, 8.9045524597])
# Iter 244; theta =  tensor([6.9366126060, 8.9063081741])
# Iter 245; theta =  tensor([6.9378490448, 8.9080314636])
# Iter 246; theta =  tensor([6.9390611649, 8.9097232819])
# Iter 247; theta =  tensor([6.9402499199, 8.9113836288])
# Iter 248; theta =  tensor([6.9414153099, 8.9130134583])
# Iter 249; theta =  tensor([6.9425578117, 8.9146137238])
# Iter 250; theta =  tensor([6.9436783791, 8.9161844254])
# Iter 251; theta =  tensor([6.9447770119, 8.9177265167])
# Iter 252; theta =  tensor([6.9458541870, 8.9192399979])
# Iter 253; theta =  tensor([6.9469099045, 8.9207258224])
# Iter 254; theta =  tensor([6.9479451180, 8.9221839905])
# Iter 255; theta =  tensor([6.9489603043, 8.9236154556])
# Iter 256; theta =  tensor([6.9499554634, 8.9250202179])
# Iter 257; theta =  tensor([6.9509315491, 8.9263992310])
# Iter 258; theta =  tensor([6.9518885612, 8.9277534485])
# Iter 259; theta =  tensor([6.9528264999, 8.9290828705])
# Iter 260; theta =  tensor([6.9537463188, 8.9303874969])
# Iter 261; theta =  tensor([6.9546480179, 8.9316682816])
# Iter 262; theta =  tensor([6.9555320740, 8.9329252243])
# Iter 263; theta =  tensor([6.9563989639, 8.9341592789])
# Iter 264; theta =  tensor([6.9572491646, 8.9353704453])
# Iter 265; theta =  tensor([6.9580826759, 8.9365596771])
# Iter 266; theta =  tensor([6.9588999748, 8.9377269745])
# Iter 267; theta =  tensor([6.9597010612, 8.9388723373])
# Iter 268; theta =  tensor([6.9604864120, 8.9399967194])
# Iter 269; theta =  tensor([6.9612565041, 8.9411010742])
# Iter 270; theta =  tensor([6.9620118141, 8.9421844482])
# Iter 271; theta =  tensor([6.9627523422, 8.9432477951])
# Iter 272; theta =  tensor([6.9634785652, 8.9442920685])
# Iter 273; theta =  tensor([6.9641904831, 8.9453172684])
# Iter 274; theta =  tensor([6.9648885727, 8.9463233948])
# Iter 275; theta =  tensor([6.9655728340, 8.9473114014])
# Iter 276; theta =  tensor([6.9662437439, 8.9482812881])
# Iter 277; theta =  tensor([6.9669017792, 8.9492330551])
# Iter 278; theta =  tensor([6.9675469398, 8.9501676559])
# Iter 279; theta =  tensor([6.9681792259, 8.9510850906])
# Iter 280; theta =  tensor([6.9687991142, 8.9519853592])
# Iter 281; theta =  tensor([6.9694070816, 8.9528694153])
# Iter 282; theta =  tensor([6.9700031281, 8.9537363052])
# Iter 283; theta =  tensor([6.9705877304, 8.9545879364])
# Iter 284; theta =  tensor([6.9711608887, 8.9554233551])
# Iter 285; theta =  tensor([6.9717226028, 8.9562435150])
# Iter 286; theta =  tensor([6.9722733498, 8.9570484161])
# Iter 287; theta =  tensor([6.9728136063, 8.9578390121])
# Iter 288; theta =  tensor([6.9733433723, 8.9586153030])
# Iter 289; theta =  tensor([6.9738626480, 8.9593772888])
# Iter 290; theta =  tensor([6.9743719101, 8.9601249695])
# Iter 291; theta =  tensor([6.9748711586, 8.9608592987])
# Iter 292; theta =  tensor([6.9753608704, 8.9615793228])
# Iter 293; theta =  tensor([6.9758410454, 8.9622859955])
# Iter 294; theta =  tensor([6.9763116837, 8.9629802704])
# Iter 295; theta =  tensor([6.9767732620, 8.9636611938])
# Iter 296; theta =  tensor([6.9772257805, 8.9643297195])
# Iter 297; theta =  tensor([6.9776692390, 8.9649858475])
# Iter 298; theta =  tensor([6.9781041145, 8.9656305313])
# Iter 299; theta =  tensor([6.9785304070, 8.9662628174])
# Iter 300; theta =  tensor([6.9789485931, 8.9668836594])
# Iter 301; theta =  tensor([6.9793586731, 8.9674930573])
# Iter 302; theta =  tensor([6.9797606468, 8.9680910110])
# Iter 303; theta =  tensor([6.9801549911, 8.9686784744])
# Iter 304; theta =  tensor([6.9805412292, 8.9692554474])
# Iter 305; theta =  tensor([6.9809203148, 8.9698209763])
# Iter 306; theta =  tensor([6.9812917709, 8.9703769684])
# Iter 307; theta =  tensor([6.9816560745, 8.9709224701])
# Iter 308; theta =  tensor([6.9820132256, 8.9714574814])
# Iter 309; theta =  tensor([6.9823632240, 8.9719829559])
# Iter 310; theta =  tensor([6.9827065468, 8.9724988937])
# Iter 311; theta =  tensor([6.9830431938, 8.9730052948])
# Iter 312; theta =  tensor([6.9833731651, 8.9735021591])
# Iter 313; theta =  tensor([6.9836969376, 8.9739904404])
# Iter 314; theta =  tensor([6.9840145111, 8.9744691849])
# Iter 315; theta =  tensor([6.9843258858, 8.9749393463])
# Iter 316; theta =  tensor([6.9846310616, 8.9754009247])
# Iter 317; theta =  tensor([6.9849300385, 8.9758539200])
# Iter 318; theta =  tensor([6.9852232933, 8.9762983322])
# Iter 319; theta =  tensor([6.9855108261, 8.9767351151])
# Iter 320; theta =  tensor([6.9857926369, 8.9771633148])
# Iter 321; theta =  tensor([6.9860692024, 8.9775838852])
# Iter 322; theta =  tensor([6.9863405228, 8.9779968262])
# Iter 323; theta =  tensor([6.9866065979, 8.9784021378])
# Iter 324; theta =  tensor([6.9868674278, 8.9787998199])
# Iter 325; theta =  tensor([6.9871230125, 8.9791898727])
# Iter 326; theta =  tensor([6.9873738289, 8.9795732498])
# Iter 327; theta =  tensor([6.9876194000, 8.9799489975])
# Iter 328; theta =  tensor([6.9878602028, 8.9803180695])
# Iter 329; theta =  tensor([6.9880962372, 8.9806804657])
# Iter 330; theta =  tensor([6.9883279800, 8.9810361862])
# Iter 331; theta =  tensor([6.9885549545, 8.9813852310])
# Iter 332; theta =  tensor([6.9887776375, 8.9817276001])
# Iter 333; theta =  tensor([6.9889960289, 8.9820642471])
# Iter 334; theta =  tensor([6.9892101288, 8.9823942184])
# Iter 335; theta =  tensor([6.9894199371, 8.9827184677])
# Iter 336; theta =  tensor([6.9896259308, 8.9830369949])
# Iter 337; theta =  tensor([6.9898276329, 8.9833498001])
# Iter 338; theta =  tensor([6.9900255203, 8.9836568832])
# Iter 339; theta =  tensor([6.9902195930, 8.9839582443])
# Iter 340; theta =  tensor([6.9904098511, 8.9842538834])
# Iter 341; theta =  tensor([6.9905962944, 8.9845438004])
# Iter 342; theta =  tensor([6.9907793999, 8.9848279953])
# Iter 343; theta =  tensor([6.9909586906, 8.9851074219])
# Iter 344; theta =  tensor([6.9911346436, 8.9853820801])
# Iter 345; theta =  tensor([6.9913072586, 8.9856510162])
# Iter 346; theta =  tensor([6.9914765358, 8.9859151840])

# %%
theta
# Out:
# tensor([6.9914765358, 8.9859151840], requires_grad=True)

# %%
# Testando com derivada manual. Sua função deve retornar algo perto de 7 e 9
theta = gd(derivada_navera, media_erros_quadrados, X, y)
# Out:
# Iter 0; theta =  tensor([0.1061585844, 0.7008764744], requires_grad=True)
# Iter 1; theta =  tensor([0.1737113446, 0.7769877315])
# Iter 2; theta =  tensor([0.2406012714, 0.8524016738])
# Iter 3; theta =  tensor([0.3068349063, 0.9271247387])
# Iter 4; theta =  tensor([0.3724186718, 1.0011632442])
# Iter 5; theta =  tensor([0.4373589754, 1.0745233297])
# Iter 6; theta =  tensor([0.5016621351, 1.1472113132])
# Iter 7; theta =  tensor([0.5653343797, 1.2192333937])
# Iter 8; theta =  tensor([0.6283819079, 1.2905955315])
# Iter 9; theta =  tensor([0.6908109188, 1.3613039255])
# Iter 10; theta =  tensor([0.7526274323, 1.4313644171])
# Iter 11; theta =  tensor([0.8138374686, 1.5007829666])
# Iter 12; theta =  tensor([0.8744469881, 1.5695655346])
# Iter 13; theta =  tensor([0.9344618917, 1.6377178431])
# Iter 14; theta =  tensor([0.9938880205, 1.7052457333])
# Iter 15; theta =  tensor([1.0527311563, 1.7721548080])
# Iter 16; theta =  tensor([1.1109970808, 1.8384507895])
# Iter 17; theta =  tensor([1.1686913967, 1.9041392803])
# Iter 18; theta =  tensor([1.2258197069, 1.9692258835])
# Iter 19; theta =  tensor([1.2823876143, 2.0337162018])
# Iter 20; theta =  tensor([1.3384006023, 2.0976154804])
# Iter 21; theta =  tensor([1.3938641548, 2.1609292030])
# Iter 22; theta =  tensor([1.4487836361, 2.2236628532])
# Iter 23; theta =  tensor([1.5031644106, 2.2858216763])
# Iter 24; theta =  tensor([1.5570117235, 2.3474109173])
# Iter 25; theta =  tensor([1.6103308201, 2.4084355831])
# Iter 26; theta =  tensor([1.6631269455, 2.4689011574])
# Iter 27; theta =  tensor([1.7154052258, 2.5288126469])
# Iter 28; theta =  tensor([1.7671706676, 2.5881750584])
# Iter 29; theta =  tensor([1.8184283972, 2.6469933987])
# Iter 30; theta =  tensor([1.8691834211, 2.7052726746])
# Iter 31; theta =  tensor([1.9194406271, 2.7630178928])
# Iter 32; theta =  tensor([1.9692049026, 2.8202340603])
# Iter 33; theta =  tensor([2.0184810162, 2.8769257069])
# Iter 34; theta =  tensor([2.0672738552, 2.9330978394])
# Iter 35; theta =  tensor([2.1155881882, 2.9887552261])
# Iter 36; theta =  tensor([2.1634285450, 3.0439026356])
# Iter 37; theta =  tensor([2.2107996941, 3.0985445976])
# Iter 38; theta =  tensor([2.2577064037, 3.1526856422])
# Iter 39; theta =  tensor([2.3041529655, 3.2063305378])
# Iter 40; theta =  tensor([2.3501441479, 3.2594838142])
# Iter 41; theta =  tensor([2.3956842422, 3.3121500015])
# Iter 42; theta =  tensor([2.4407777786, 3.3643333912])
# Iter 43; theta =  tensor([2.4854290485, 3.4160385132])
# Iter 44; theta =  tensor([2.5296423435, 3.4672696590])
# Iter 45; theta =  tensor([2.5734221935, 3.5180313587])
# Iter 46; theta =  tensor([2.6167726517, 3.5683276653])
# Iter 47; theta =  tensor([2.6596980095, 3.6181631088])
# Iter 48; theta =  tensor([2.7022025585, 3.6675417423])
# Iter 49; theta =  tensor([2.7442901134, 3.7164676189])
# Iter 50; theta =  tensor([2.7859649658, 3.7649450302])
# Iter 51; theta =  tensor([2.8272311687, 3.8129782677])
# Iter 52; theta =  tensor([2.8680927753, 3.8605711460])
# Iter 53; theta =  tensor([2.9085538387, 3.9077277184])
# Iter 54; theta =  tensor([2.9486181736, 3.9544520378])
# Iter 55; theta =  tensor([2.9882895947, 4.0007481575])
# Iter 56; theta =  tensor([3.0275719166, 4.0466198921])
# Iter 57; theta =  tensor([3.0664691925, 4.0920710564])
# Iter 58; theta =  tensor([3.1049849987, 4.1371054649])
# Iter 59; theta =  tensor([3.1431231499, 4.1817274094])
# Iter 60; theta =  tensor([3.1808874607, 4.2259402275])
# Iter 61; theta =  tensor([3.2182815075, 4.2697477341])
# Iter 62; theta =  tensor([3.2553088665, 4.3131537437])
# Iter 63; theta =  tensor([3.2919733524, 4.3561615944])
# Iter 64; theta =  tensor([3.3282783031, 4.3987751007])
# Iter 65; theta =  tensor([3.3642272949, 4.4409980774])
# Iter 66; theta =  tensor([3.3998239040, 4.4828338623])
# Iter 67; theta =  tensor([3.4350714684, 4.5242862701])
# Iter 68; theta =  tensor([3.4699735641, 4.5653586388])
# Iter 69; theta =  tensor([3.5045332909, 4.6060543060])
# Iter 70; theta =  tensor([3.5387542248, 4.6463770866])
# Iter 71; theta =  tensor([3.5726397038, 4.6863298416])
# Iter 72; theta =  tensor([3.6061930656, 4.7259163857])
# Iter 73; theta =  tensor([3.6394174099, 4.7651400566])
# Iter 74; theta =  tensor([3.6723160744, 4.8040041924])
# Iter 75; theta =  tensor([3.7048923969, 4.8425121307])
# Iter 76; theta =  tensor([3.7371492386, 4.8806667328])
# Iter 77; theta =  tensor([3.7690899372, 4.9184718132])
# Iter 78; theta =  tensor([3.8007175922, 4.9559302330])
# Iter 79; theta =  tensor([3.8320353031, 4.9930453300])
# Iter 80; theta =  tensor([3.8630459309, 5.0298199654])
# Iter 81; theta =  tensor([3.8937525749, 5.0662574768])
# Iter 82; theta =  tensor([3.9241583347, 5.1023607254])
# Iter 83; theta =  tensor([3.9542660713, 5.1381330490])
# Iter 84; theta =  tensor([3.9840786457, 5.1735773087])
# Iter 85; theta =  tensor([4.0135989189, 5.2086963654])
# Iter 86; theta =  tensor([4.0428299904, 5.2434935570])
# Iter 87; theta =  tensor([4.0717744827, 5.2779717445])
# Iter 88; theta =  tensor([4.1004352570, 5.3121337891])
# Iter 89; theta =  tensor([4.1288151741, 5.3459825516])
# Iter 90; theta =  tensor([4.1569170952, 5.3795208931])
# Iter 91; theta =  tensor([4.1847434044, 5.4127516747])
# Iter 92; theta =  tensor([4.2122969627, 5.4456777573])
# Iter 93; theta =  tensor([4.2395806313, 5.4783020020])
# Iter 94; theta =  tensor([4.2665967941, 5.5106267929])
# Iter 95; theta =  tensor([4.2933483124, 5.5426554680])
# Iter 96; theta =  tensor([4.3198375702, 5.5743904114])
# Iter 97; theta =  tensor([4.3460674286, 5.6058344841])
# Iter 98; theta =  tensor([4.3720402718, 5.6369900703])
# Iter 99; theta =  tensor([4.3977584839, 5.6678600311])
# Iter 100; theta =  tensor([4.4232244492, 5.6984467506])
# Iter 101; theta =  tensor([4.4484410286, 5.7287530899])
# Iter 102; theta =  tensor([4.4734106064, 5.7587814331])
# Iter 103; theta =  tensor([4.4981355667, 5.7885341644])
# Iter 104; theta =  tensor([4.5226178169, 5.8180141449])
# Iter 105; theta =  tensor([4.5468602180, 5.8472237587])
# Iter 106; theta =  tensor([4.5708651543, 5.8761653900])
# Iter 107; theta =  tensor([4.5946350098, 5.9048418999])
# Iter 108; theta =  tensor([4.6181716919, 5.9332551956])
# Iter 109; theta =  tensor([4.6414780617, 5.9614081383])
# Iter 110; theta =  tensor([4.6645560265, 5.9893026352])
# Iter 111; theta =  tensor([4.6874079704, 6.0169415474])
# Iter 112; theta =  tensor([4.7100358009, 6.0443267822])
# Iter 113; theta =  tensor([4.7324419022, 6.0714607239])
# Iter 114; theta =  tensor([4.7546286583, 6.0983457565])
# Iter 115; theta =  tensor([4.7765979767, 6.1249842644])
# Iter 116; theta =  tensor([4.7983517647, 6.1513786316])
# Iter 117; theta =  tensor([4.8198924065, 6.1775307655])
# Iter 118; theta =  tensor([4.8412222862, 6.2034430504])
# Iter 119; theta =  tensor([4.8623433113, 6.2291178703])
# Iter 120; theta =  tensor([4.8832573891, 6.2545571327])
# Iter 121; theta =  tensor([4.9039664268, 6.2797627449])
# Iter 122; theta =  tensor([4.9244728088, 6.3047375679])
# Iter 123; theta =  tensor([4.9447779655, 6.3294830322])
# Iter 124; theta =  tensor([4.9648842812, 6.3540015221])
# Iter 125; theta =  tensor([4.9847936630, 6.3782949448])
# Iter 126; theta =  tensor([5.0045080185, 6.4023656845])
# Iter 127; theta =  tensor([5.0240292549, 6.4262156487])
# Iter 128; theta =  tensor([5.0433592796, 6.4498467445])
# Iter 129; theta =  tensor([5.0625000000, 6.4732613564])
# Iter 130; theta =  tensor([5.0814533234, 6.4964609146])
# Iter 131; theta =  tensor([5.1002206802, 6.5194478035])
# Iter 132; theta =  tensor([5.1188044548, 6.5422239304])
# Iter 133; theta =  tensor([5.1372060776, 6.5647912025])
# Iter 134; theta =  tensor([5.1554274559, 6.5871510506])
# Iter 135; theta =  tensor([5.1734704971, 6.6093058586])
# Iter 136; theta =  tensor([5.1913366318, 6.6312575340])
# Iter 137; theta =  tensor([5.2090277672, 6.6530079842])
# Iter 138; theta =  tensor([5.2265458107, 6.6745586395])
# Iter 139; theta =  tensor([5.2438921928, 6.6959118843])
# Iter 140; theta =  tensor([5.2610683441, 6.7170691490])
# Iter 141; theta =  tensor([5.2780766487, 6.7380323410])
# Iter 142; theta =  tensor([5.2949180603, 6.7588028908])
# Iter 143; theta =  tensor([5.3115944862, 6.7793831825])
# Iter 144; theta =  tensor([5.3281078339, 6.7997746468])
# Iter 145; theta =  tensor([5.3444595337, 6.8199787140])
# Iter 146; theta =  tensor([5.3606510162, 6.8399977684])
# Iter 147; theta =  tensor([5.3766837120, 6.8598332405])
# Iter 148; theta =  tensor([5.3925595284, 6.8794865608])
# Iter 149; theta =  tensor([5.4082798958, 6.8989596367])
# Iter 150; theta =  tensor([5.4238462448, 6.9182538986])
# Iter 151; theta =  tensor([5.4392600060, 6.9373712540])
# Iter 152; theta =  tensor([5.4545230865, 6.9563131332])
# Iter 153; theta =  tensor([5.4696364403, 6.9750809669])
# Iter 154; theta =  tensor([5.4846019745, 6.9936766624])
# Iter 155; theta =  tensor([5.4994211197, 7.0121021271])
# Iter 156; theta =  tensor([5.5140948296, 7.0303583145])
# Iter 157; theta =  tensor([5.5286250114, 7.0484471321])
# Iter 158; theta =  tensor([5.5430130959, 7.0663700104])
# Iter 159; theta =  tensor([5.5572600365, 7.0841283798])
# Iter 160; theta =  tensor([5.5713677406, 7.1017236710])
# Iter 161; theta =  tensor([5.5853371620, 7.1191573143])
# Iter 162; theta =  tensor([5.5991697311, 7.1364312172])
# Iter 163; theta =  tensor([5.6128668785, 7.1535468102])
# Iter 164; theta =  tensor([5.6264300346, 7.1705050468])
# Iter 165; theta =  tensor([5.6398601532, 7.1873078346])
# Iter 166; theta =  tensor([5.6531586647, 7.2039561272])
# Iter 167; theta =  tensor([5.6663269997, 7.2204518318])
# Iter 168; theta =  tensor([5.6793665886, 7.2367963791])
# Iter 169; theta =  tensor([5.6922783852, 7.2529907227])
# Iter 170; theta =  tensor([5.7050638199, 7.2690362930])
# Iter 171; theta =  tensor([5.7177243233, 7.2849349976])
# Iter 172; theta =  tensor([5.7302608490, 7.3006877899])
# Iter 173; theta =  tensor([5.7426743507, 7.3162956238])
# Iter 174; theta =  tensor([5.7549662590, 7.3317604065])
# Iter 175; theta =  tensor([5.7671380043, 7.3470830917])
# Iter 176; theta =  tensor([5.7791905403, 7.3622655869])
# Iter 177; theta =  tensor([5.7911252975, 7.3773083687])
# Iter 178; theta =  tensor([5.8029432297, 7.3922133446])
# Iter 179; theta =  tensor([5.8146452904, 7.4069814682])
# Iter 180; theta =  tensor([5.8262329102, 7.4216141701])
# Iter 181; theta =  tensor([5.8377070427, 7.4361124039])
# Iter 182; theta =  tensor([5.8490686417, 7.4504776001])
# Iter 183; theta =  tensor([5.8603191376, 7.4647111893])
# Iter 184; theta =  tensor([5.8714594841, 7.4788141251])
# Iter 185; theta =  tensor([5.8824911118, 7.4927873611])
# Iter 186; theta =  tensor([5.8934144974, 7.5066323280])
# Iter 187; theta =  tensor([5.9042310715, 7.5203504562])
# Iter 188; theta =  tensor([5.9149417877, 7.5339426994])
# Iter 189; theta =  tensor([5.9255475998, 7.5474100113])
# Iter 190; theta =  tensor([5.9360494614, 7.5607538223])
# Iter 191; theta =  tensor([5.9464488029, 7.5739750862])
# Iter 192; theta =  tensor([5.9567461014, 7.5870752335])
# Iter 193; theta =  tensor([5.9669427872, 7.6000547409])
# Iter 194; theta =  tensor([5.9770398140, 7.6129155159])
# Iter 195; theta =  tensor([5.9870376587, 7.6256580353])
# Iter 196; theta =  tensor([5.9969377518, 7.6382837296])
# Iter 197; theta =  tensor([6.0067410469, 7.6507935524])
# Iter 198; theta =  tensor([6.0164484978, 7.6631884575])
# Iter 199; theta =  tensor([6.0260605812, 7.6754693985])
# Iter 200; theta =  tensor([6.0355787277, 7.6876378059])
# Iter 201; theta =  tensor([6.0450038910, 7.6996946335])
# Iter 202; theta =  tensor([6.0543365479, 7.7116408348])
# Iter 203; theta =  tensor([6.0635781288, 7.7234773636])
# Iter 204; theta =  tensor([6.0727291107, 7.7352051735])
# Iter 205; theta =  tensor([6.0817904472, 7.7468252182])
# Iter 206; theta =  tensor([6.0907630920, 7.7583384514])
# Iter 207; theta =  tensor([6.0996479988, 7.7697463036])
# Iter 208; theta =  tensor([6.1084461212, 7.7810492516])
# Iter 209; theta =  tensor([6.1171579361, 7.7922482491])
# Iter 210; theta =  tensor([6.1257848740, 7.8033447266])
# Iter 211; theta =  tensor([6.1343274117, 7.8143391609])
# Iter 212; theta =  tensor([6.1427860260, 7.8252329826])
# Iter 213; theta =  tensor([6.1511621475, 7.8360266685])
# Iter 214; theta =  tensor([6.1594562531, 7.8467211723])
# Iter 215; theta =  tensor([6.1676692963, 7.8573174477])
# Iter 216; theta =  tensor([6.1758017540, 7.8678164482])
# Iter 217; theta =  tensor([6.1838545799, 7.8782191277])
# Iter 218; theta =  tensor([6.1918287277, 7.8885264397])
# Iter 219; theta =  tensor([6.1997246742, 7.8987388611])
# Iter 220; theta =  tensor([6.2075433731, 7.9088578224])
# Iter 221; theta =  tensor([6.2152857780, 7.9188838005])
# Iter 222; theta =  tensor([6.2229523659, 7.9288177490])
# Iter 223; theta =  tensor([6.2305440903, 7.9386606216])
# Iter 224; theta =  tensor([6.2380614281, 7.9484128952])
# Iter 225; theta =  tensor([6.2455053329, 7.9580755234])
# Iter 226; theta =  tensor([6.2528762817, 7.9676494598])
# Iter 227; theta =  tensor([6.2601752281, 7.9771356583])
# Iter 228; theta =  tensor([6.2674026489, 7.9865345955])
# Iter 229; theta =  tensor([6.2745594978, 7.9958472252])
# Iter 230; theta =  tensor([6.2816462517, 8.0050745010])
# Iter 231; theta =  tensor([6.2886638641, 8.0142173767])
# Iter 232; theta =  tensor([6.2956128120, 8.0232763290])
# Iter 233; theta =  tensor([6.3024935722, 8.0322513580])
# Iter 234; theta =  tensor([6.3093070984, 8.0411443710])
# Iter 235; theta =  tensor([6.3160538673, 8.0499553680])
# Iter 236; theta =  tensor([6.3227348328, 8.0586862564])
# Iter 237; theta =  tensor([6.3293504715, 8.0673360825])
# Iter 238; theta =  tensor([6.3359012604, 8.0759067535])
# Iter 239; theta =  tensor([6.3423881531, 8.0843992233])
# Iter 240; theta =  tensor([6.3488116264, 8.0928134918])
# Iter 241; theta =  tensor([6.3551721573, 8.1011505127])
# Iter 242; theta =  tensor([6.3614702225, 8.1094112396])
# Iter 243; theta =  tensor([6.3677067757, 8.1175956726])
# Iter 244; theta =  tensor([6.3738822937, 8.1257047653])
# Iter 245; theta =  tensor([6.3799977303, 8.1337394714])
# Iter 246; theta =  tensor([6.3860530853, 8.1417007446])
# Iter 247; theta =  tensor([6.3920493126, 8.1495885849])
# Iter 248; theta =  tensor([6.3979868889, 8.1574039459])
# Iter 249; theta =  tensor([6.4038662910, 8.1651477814])
# Iter 250; theta =  tensor([6.4096884727, 8.1728200912])
# Iter 251; theta =  tensor([6.4154534340, 8.1804227829])
# Iter 252; theta =  tensor([6.4211621284, 8.1879549026])
# Iter 253; theta =  tensor([6.4268150330, 8.1954183578])
# Iter 254; theta =  tensor([6.4324126244, 8.2028131485])
# Iter 255; theta =  tensor([6.4379553795, 8.2101402283])
# Iter 256; theta =  tensor([6.4434437752, 8.2173995972])
# Iter 257; theta =  tensor([6.4488787651, 8.2245922089])
# Iter 258; theta =  tensor([6.4542603493, 8.2317190170])
# Iter 259; theta =  tensor([6.4595894814, 8.2387800217])
# Iter 260; theta =  tensor([6.4648666382, 8.2457761765])
# Iter 261; theta =  tensor([6.4700918198, 8.2527084351])
# Iter 262; theta =  tensor([6.4752659798, 8.2595767975])
# Iter 263; theta =  tensor([6.4803895950, 8.2663822174])
# Iter 264; theta =  tensor([6.4854631424, 8.2731256485])
# Iter 265; theta =  tensor([6.4904870987, 8.2798070908])
# Iter 266; theta =  tensor([6.4954619408, 8.2864265442])
# Iter 267; theta =  tensor([6.5003881454, 8.2929859161])
# Iter 268; theta =  tensor([6.5052661896, 8.2994842529])
# Iter 269; theta =  tensor([6.5100965500, 8.3059234619])
# Iter 270; theta =  tensor([6.5148797035, 8.3123035431])
# Iter 271; theta =  tensor([6.5196161270, 8.3186244965])
# Iter 272; theta =  tensor([6.5243062973, 8.3248872757])
# Iter 273; theta =  tensor([6.5289506912, 8.3310928345])
# Iter 274; theta =  tensor([6.5335493088, 8.3372411728])
# Iter 275; theta =  tensor([6.5381031036, 8.3433332443])
# Iter 276; theta =  tensor([6.5426125526, 8.3493690491])
# Iter 277; theta =  tensor([6.5470776558, 8.3553495407])
# Iter 278; theta =  tensor([6.5514993668, 8.3612756729])
# Iter 279; theta =  tensor([6.5558776855, 8.3671474457])
# Iter 280; theta =  tensor([6.5602130890, 8.3729648590])
# Iter 281; theta =  tensor([6.5645060539, 8.3787288666])
# Iter 282; theta =  tensor([6.5687570572, 8.3844404221])
# Iter 283; theta =  tensor([6.5729665756, 8.3900995255])
# Iter 284; theta =  tensor([6.5771350861, 8.3957061768])
# Iter 285; theta =  tensor([6.5812630653, 8.4012613297])
# Iter 286; theta =  tensor([6.5853505135, 8.4067659378])
# Iter 287; theta =  tensor([6.5893979073, 8.4122200012])
# Iter 288; theta =  tensor([6.5934057236, 8.4176235199])
# Iter 289; theta =  tensor([6.5973744392, 8.4229774475])
# Iter 290; theta =  tensor([6.6013045311, 8.4282817841])
# Iter 291; theta =  tensor([6.6051959991, 8.4335374832])
# Iter 292; theta =  tensor([6.6090493202, 8.4387454987])
# Iter 293; theta =  tensor([6.6128649712, 8.4439048767])
# Iter 294; theta =  tensor([6.6166434288, 8.4490175247])
# Iter 295; theta =  tensor([6.6203851700, 8.4540834427])
# Iter 296; theta =  tensor([6.6240901947, 8.4591026306])
# Iter 297; theta =  tensor([6.6277589798, 8.4640750885])
# Iter 298; theta =  tensor([6.6313920021, 8.4690017700])
# Iter 299; theta =  tensor([6.6349892616, 8.4738836288])
# Iter 300; theta =  tensor([6.6385517120, 8.4787206650])
# Iter 301; theta =  tensor([6.6420793533, 8.4835128784])
# Iter 302; theta =  tensor([6.6455721855, 8.4882612228])
# Iter 303; theta =  tensor([6.6490311623, 8.4929666519])
# Iter 304; theta =  tensor([6.6524562836, 8.4976282120])
# Iter 305; theta =  tensor([6.6558480263, 8.5022468567])
# Iter 306; theta =  tensor([6.6592063904, 8.5068235397])
# Iter 307; theta =  tensor([6.6625318527, 8.5113582611])
# Iter 308; theta =  tensor([6.6658248901, 8.5158510208])
# Iter 309; theta =  tensor([6.6690859795, 8.5203027725])
# Iter 310; theta =  tensor([6.6723151207, 8.5247135162])
# Iter 311; theta =  tensor([6.6755127907, 8.5290832520])
# Iter 312; theta =  tensor([6.6786789894, 8.5334129333])
# Iter 313; theta =  tensor([6.6818141937, 8.5377035141])
# Iter 314; theta =  tensor([6.6849188805, 8.5419540405])
# Iter 315; theta =  tensor([6.6879930496, 8.5461654663])
# Iter 316; theta =  tensor([6.6910371780, 8.5503387451])
# Iter 317; theta =  tensor([6.6940517426, 8.5544729233])
# Iter 318; theta =  tensor([6.6970367432, 8.5585699081])
# Iter 319; theta =  tensor([6.6999926567, 8.5626287460])
# Iter 320; theta =  tensor([6.7029194832, 8.5666503906])
# Iter 321; theta =  tensor([6.7058176994, 8.5706348419])
# Iter 322; theta =  tensor([6.7086877823, 8.5745830536])
# Iter 323; theta =  tensor([6.7115297318, 8.5784950256])
# Iter 324; theta =  tensor([6.7143440247, 8.5823707581])
# Iter 325; theta =  tensor([6.7171306610, 8.5862112045])
# Iter 326; theta =  tensor([6.7198901176, 8.5900163651])
# Iter 327; theta =  tensor([6.7226228714, 8.5937862396])
# Iter 328; theta =  tensor([6.7253289223, 8.5975217819])
# Iter 329; theta =  tensor([6.7280082703, 8.6012229919])
# Iter 330; theta =  tensor([6.7306613922, 8.6048898697])
# Iter 331; theta =  tensor([6.7332887650, 8.6085233688])
# Iter 332; theta =  tensor([6.7358903885, 8.6121234894])
# Iter 333; theta =  tensor([6.7384667397, 8.6156902313])
# Iter 334; theta =  tensor([6.7410178185, 8.6192245483])
# Iter 335; theta =  tensor([6.7435441017, 8.6227264404])
# Iter 336; theta =  tensor([6.7460455894, 8.6261959076])
# Iter 337; theta =  tensor([6.7485227585, 8.6296339035])
# Iter 338; theta =  tensor([6.7509756088, 8.6330394745])
# Iter 339; theta =  tensor([6.7534046173, 8.6364145279])
# Iter 340; theta =  tensor([6.7558097839, 8.6397581100])
# Iter 341; theta =  tensor([6.7581915855, 8.6430711746])
# Iter 342; theta =  tensor([6.7605500221, 8.6463537216])
# Iter 343; theta =  tensor([6.7628855705, 8.6496057510])
# Iter 344; theta =  tensor([6.7651982307, 8.6528282166])
# Iter 345; theta =  tensor([6.7674884796, 8.6560211182])
# Iter 346; theta =  tensor([6.7697563171, 8.6591844559])
# Iter 347; theta =  tensor([6.7720017433, 8.6623191833])
# Iter 348; theta =  tensor([6.7742252350, 8.6654243469])
# Iter 349; theta =  tensor([6.7764272690, 8.6685018539])
# Iter 350; theta =  tensor([6.7786078453, 8.6715507507])
# Iter 351; theta =  tensor([6.7807669640, 8.6745719910])
# Iter 352; theta =  tensor([6.7829051018, 8.6775646210])
# Iter 353; theta =  tensor([6.7850222588, 8.6805305481])
# Iter 354; theta =  tensor([6.7871189117, 8.6834688187])
# Iter 355; theta =  tensor([6.7891950607, 8.6863803864])
# Iter 356; theta =  tensor([6.7912507057, 8.6892652512])
# Iter 357; theta =  tensor([6.7932863235, 8.6921234131])
# Iter 358; theta =  tensor([6.7953019142, 8.6949548721])
# Iter 359; theta =  tensor([6.7972979546, 8.6977605820])
# Iter 360; theta =  tensor([6.7992744446, 8.7005405426])
# Iter 361; theta =  tensor([6.8012318611, 8.7032947540])
# Iter 362; theta =  tensor([6.8031702042, 8.7060241699])
# Iter 363; theta =  tensor([6.8050894737, 8.7087278366])
# Iter 364; theta =  tensor([6.8069901466, 8.7114067078])
# Iter 365; theta =  tensor([6.8088722229, 8.7140607834])
# Iter 366; theta =  tensor([6.8107357025, 8.7166910172])
# Iter 367; theta =  tensor([6.8125810623, 8.7192974091])
# Iter 368; theta =  tensor([6.8144083023, 8.7218790054])
# Iter 369; theta =  tensor([6.8162178993, 8.7244377136])
# Iter 370; theta =  tensor([6.8180098534, 8.7269725800])
# Iter 371; theta =  tensor([6.8197841644, 8.7294836044])
# Iter 372; theta =  tensor([6.8215413094, 8.7319717407])
# Iter 373; theta =  tensor([6.8232812881, 8.7344369888])
# Iter 374; theta =  tensor([6.8250041008, 8.7368793488])
# Iter 375; theta =  tensor([6.8267102242, 8.7392997742])
# Iter 376; theta =  tensor([6.8283996582, 8.7416982651])
# Iter 377; theta =  tensor([6.8300724030, 8.7440738678])
# Iter 378; theta =  tensor([6.8317289352, 8.7464284897])
# Iter 379; theta =  tensor([6.8333692551, 8.7487611771])
# Iter 380; theta =  tensor([6.8349938393, 8.7510719299])
# Iter 381; theta =  tensor([6.8366022110, 8.7533617020])
# Iter 382; theta =  tensor([6.8381948471, 8.7556304932])
# Iter 383; theta =  tensor([6.8397722244, 8.7578783035])
# Iter 384; theta =  tensor([6.8413338661, 8.7601060867])
# Iter 385; theta =  tensor([6.8428802490, 8.7623128891])
# Iter 386; theta =  tensor([6.8444118500, 8.7644996643])
# Iter 387; theta =  tensor([6.8459281921, 8.7666664124])
# Iter 388; theta =  tensor([6.8474297523, 8.7688131332])
# Iter 389; theta =  tensor([6.8489170074, 8.7709398270])
# Iter 390; theta =  tensor([6.8503894806, 8.7730474472])
# Iter 391; theta =  tensor([6.8518476486, 8.7751350403])
# Iter 392; theta =  tensor([6.8532915115, 8.7772035599])
# Iter 393; theta =  tensor([6.8547215462, 8.7792530060])
# Iter 394; theta =  tensor([6.8561372757, 8.7812833786])
# Iter 395; theta =  tensor([6.8575391769, 8.7832956314])
# Iter 396; theta =  tensor([6.8589277267, 8.7852897644])
# Iter 397; theta =  tensor([6.8603024483, 8.7872648239])
# Iter 398; theta =  tensor([6.8616638184, 8.7892217636])
# Iter 399; theta =  tensor([6.8630118370, 8.7911605835])
# Iter 400; theta =  tensor([6.8643469810, 8.7930822372])
# Iter 401; theta =  tensor([6.8656687737, 8.7949857712])
# Iter 402; theta =  tensor([6.8669776917, 8.7968721390])
# Iter 403; theta =  tensor([6.8682742119, 8.7987413406])
# Iter 404; theta =  tensor([6.8695578575, 8.8005933762])
# Iter 405; theta =  tensor([6.8708291054, 8.8024282455])
# Iter 406; theta =  tensor([6.8720879555, 8.8042459488])
# Iter 407; theta =  tensor([6.8733344078, 8.8060474396])
# Iter 408; theta =  tensor([6.8745684624, 8.8078317642])
# Iter 409; theta =  tensor([6.8757905960, 8.8095998764])
# Iter 410; theta =  tensor([6.8770008087, 8.8113517761])
# Iter 411; theta =  tensor([6.8781991005, 8.8130874634])
# Iter 412; theta =  tensor([6.8793859482, 8.8148069382])
# Iter 413; theta =  tensor([6.8805613518, 8.8165111542])
# Iter 414; theta =  tensor([6.8817253113, 8.8181991577])
# Iter 415; theta =  tensor([6.8828778267, 8.8198719025])
# Iter 416; theta =  tensor([6.8840188980, 8.8215293884])
# Iter 417; theta =  tensor([6.8851490021, 8.8231716156])
# Iter 418; theta =  tensor([6.8862681389, 8.8247985840])
# Iter 419; theta =  tensor([6.8873763084, 8.8264102936])
# Iter 420; theta =  tensor([6.8884735107, 8.8280076981])
# Iter 421; theta =  tensor([6.8895602226, 8.8295898438])
# Iter 422; theta =  tensor([6.8906359673, 8.8311576843])
# Iter 423; theta =  tensor([6.8917012215, 8.8327112198])
# Iter 424; theta =  tensor([6.8927564621, 8.8342504501])
# Iter 425; theta =  tensor([6.8938012123, 8.8357753754])
# Iter 426; theta =  tensor([6.8948359489, 8.8372869492])
# Iter 427; theta =  tensor([6.8958601952, 8.8387842178])
# Iter 428; theta =  tensor([6.8968749046, 8.8402681351])
# Iter 429; theta =  tensor([6.8978796005, 8.8417377472])
# Iter 430; theta =  tensor([6.8988742828, 8.8431940079])
# Iter 431; theta =  tensor([6.8998594284, 8.8446369171])
# Iter 432; theta =  tensor([6.9008350372, 8.8460664749])
# Iter 433; theta =  tensor([6.9018011093, 8.8474826813])
# Iter 434; theta =  tensor([6.9027576447, 8.8488864899])
# Iter 435; theta =  tensor([6.9037046432, 8.8502769470])
# Iter 436; theta =  tensor([6.9046425819, 8.8516550064])
# Iter 437; theta =  tensor([6.9055714607, 8.8530197144])
# Iter 438; theta =  tensor([6.9064912796, 8.8543720245])
# Iter 439; theta =  tensor([6.9074020386, 8.8557119370])
# Iter 440; theta =  tensor([6.9083037376, 8.8570394516])
# Iter 441; theta =  tensor([6.9091968536, 8.8583555222])
# Iter 442; theta =  tensor([6.9100813866, 8.8596591949])
# Iter 443; theta =  tensor([6.9109573364, 8.8609504700])
# Iter 444; theta =  tensor([6.9118247032, 8.8622303009])
# Iter 445; theta =  tensor([6.9126834869, 8.8634977341])
# Iter 446; theta =  tensor([6.9135336876, 8.8647537231])
# Iter 447; theta =  tensor([6.9143757820, 8.8659982681])
# Iter 448; theta =  tensor([6.9152097702, 8.8672313690])
# Iter 449; theta =  tensor([6.9160356522, 8.8684530258])
# Iter 450; theta =  tensor([6.9168534279, 8.8696632385])
# Iter 451; theta =  tensor([6.9176630974, 8.8708629608])
# Iter 452; theta =  tensor([6.9184651375, 8.8720512390])
# Iter 453; theta =  tensor([6.9192590714, 8.8732290268])
# Iter 454; theta =  tensor([6.9200453758, 8.8743953705])
# Iter 455; theta =  tensor([6.9208240509, 8.8755512238])
# Iter 456; theta =  tensor([6.9215950966, 8.8766965866])
# Iter 457; theta =  tensor([6.9223585129, 8.8778314590])
# Iter 458; theta =  tensor([6.9231142998, 8.8789558411])
# Iter 459; theta =  tensor([6.9238629341, 8.8800697327])
# Iter 460; theta =  tensor([6.9246044159, 8.8811731339])
# Iter 461; theta =  tensor([6.9253387451, 8.8822669983])
# Iter 462; theta =  tensor([6.9260659218, 8.8833503723])
# Iter 463; theta =  tensor([6.9267859459, 8.8844242096])
# Iter 464; theta =  tensor([6.9274988174, 8.8854875565])
# Iter 465; theta =  tensor([6.9282045364, 8.8865413666])
# Iter 466; theta =  tensor([6.9289035797, 8.8875856400])
# Iter 467; theta =  tensor([6.9295959473, 8.8886203766])
# Iter 468; theta =  tensor([6.9302811623, 8.8896455765])
# Iter 469; theta =  tensor([6.9309597015, 8.8906612396])
# Iter 470; theta =  tensor([6.9316320419, 8.8916673660])
# Iter 471; theta =  tensor([6.9322977066, 8.8926649094])
# Iter 472; theta =  tensor([6.9329566956, 8.8936529160])
# Iter 473; theta =  tensor([6.9336094856, 8.8946313858])
# Iter 474; theta =  tensor([6.9342556000, 8.8956012726])
# Iter 475; theta =  tensor([6.9348955154, 8.8965625763])
# Iter 476; theta =  tensor([6.9355292320, 8.8975143433])
# Iter 477; theta =  tensor([6.9361567497, 8.8984575272])
# Iter 478; theta =  tensor([6.9367780685, 8.8993921280])
# Iter 479; theta =  tensor([6.9373936653, 8.9003181458])
# Iter 480; theta =  tensor([6.9380030632, 8.9012355804])
# Iter 481; theta =  tensor([6.9386067390, 8.9021444321])
# Iter 482; theta =  tensor([6.9392042160, 8.9030456543])
# Iter 483; theta =  tensor([6.9397959709, 8.9039382935])
# Iter 484; theta =  tensor([6.9403820038, 8.9048223495])
# Iter 485; theta =  tensor([6.9409623146, 8.9056987762])
# Iter 486; theta =  tensor([6.9415369034, 8.9065666199])
# Iter 487; theta =  tensor([6.9421057701, 8.9074268341])
# Iter 488; theta =  tensor([6.9426693916, 8.9082794189])
# Iter 489; theta =  tensor([6.9432272911, 8.9091234207])
# Iter 490; theta =  tensor([6.9437799454, 8.9099597931])
# Iter 491; theta =  tensor([6.9443268776, 8.9107885361])
# Iter 492; theta =  tensor([6.9448685646, 8.9116096497])
# Iter 493; theta =  tensor([6.9454050064, 8.9124231339])
# Iter 494; theta =  tensor([6.9459362030, 8.9132289886])
# Iter 495; theta =  tensor([6.9464621544, 8.9140281677])
# Iter 496; theta =  tensor([6.9469833374, 8.9148197174])
# Iter 497; theta =  tensor([6.9474992752, 8.9156036377])
# Iter 498; theta =  tensor([6.9480099678, 8.9163808823])
# Iter 499; theta =  tensor([6.9485158920, 8.9171504974])
# Iter 500; theta =  tensor([6.9490170479, 8.9179134369])
# Iter 501; theta =  tensor([6.9495129585, 8.9186687469])
# Iter 502; theta =  tensor([6.9500041008, 8.9194173813])
# Iter 503; theta =  tensor([6.9504904747, 8.9201593399])
# Iter 504; theta =  tensor([6.9509720802, 8.9208946228])
# Iter 505; theta =  tensor([6.9514489174, 8.9216232300])
# Iter 506; theta =  tensor([6.9519214630, 8.9223451614])
# Iter 507; theta =  tensor([6.9523892403, 8.9230604172])
# Iter 508; theta =  tensor([6.9528527260, 8.9237689972])
# Iter 509; theta =  tensor([6.9533114433, 8.9244709015])
# Iter 510; theta =  tensor([6.9537658691, 8.9251661301])
# Iter 511; theta =  tensor([6.9542155266, 8.9258546829])
# Iter 512; theta =  tensor([6.9546608925, 8.9265375137])
# Iter 513; theta =  tensor([6.9551019669, 8.9272136688])
# Iter 514; theta =  tensor([6.9555387497, 8.9278841019])
# Iter 515; theta =  tensor([6.9559712410, 8.9285478592])
# Iter 516; theta =  tensor([6.9563994408, 8.9292058945])
# Iter 517; theta =  tensor([6.9568238258, 8.9298572540])
# Iter 518; theta =  tensor([6.9572439194, 8.9305028915])
# Iter 519; theta =  tensor([6.9576597214, 8.9311428070])
# Iter 520; theta =  tensor([6.9580717087, 8.9317770004])
# Iter 521; theta =  tensor([6.9584794044, 8.9324054718])
# Iter 522; theta =  tensor([6.9588832855, 8.9330282211])
# Iter 523; theta =  tensor([6.9592833519, 8.9336452484])
# Iter 524; theta =  tensor([6.9596796036, 8.9342565536])
# Iter 525; theta =  tensor([6.9600720406, 8.9348621368])
# Iter 526; theta =  tensor([6.9604606628, 8.9354619980])
# Iter 527; theta =  tensor([6.9608454704, 8.9360561371])
# Iter 528; theta =  tensor([6.9612264633, 8.9366445541])
# Iter 529; theta =  tensor([6.9616036415, 8.9372282028])
# Iter 530; theta =  tensor([6.9619770050, 8.9378061295])
# Iter 531; theta =  tensor([6.9623470306, 8.9383783340])
# Iter 532; theta =  tensor([6.9627132416, 8.9389457703])
# Iter 533; theta =  tensor([6.9630761147, 8.9395074844])
# Iter 534; theta =  tensor([6.9634351730, 8.9400644302])
# Iter 535; theta =  tensor([6.9637908936, 8.9406166077])
# Iter 536; theta =  tensor([6.9641432762, 8.9411630630])
# Iter 537; theta =  tensor([6.9644918442, 8.9417047501])
# Iter 538; theta =  tensor([6.9648370743, 8.9422416687])
# Iter 539; theta =  tensor([6.9651789665, 8.9427738190])
# Iter 540; theta =  tensor([6.9655175209, 8.9433012009])
# Iter 541; theta =  tensor([6.9658527374, 8.9438228607])
# Iter 542; theta =  tensor([6.9661846161, 8.9443397522])
# Iter 543; theta =  tensor([6.9665136337, 8.9448518753])
# Iter 544; theta =  tensor([6.9668393135, 8.9453592300])
# Iter 545; theta =  tensor([6.9671616554, 8.9458627701])
# Iter 546; theta =  tensor([6.9674811363, 8.9463615417])
# Iter 547; theta =  tensor([6.9677972794, 8.9468555450])
# Iter 548; theta =  tensor([6.9681105614, 8.9473447800])
# Iter 549; theta =  tensor([6.9684205055, 8.9478292465])
# Iter 550; theta =  tensor([6.9687275887, 8.9483098984])
# Iter 551; theta =  tensor([6.9690318108, 8.9487857819])
# Iter 552; theta =  tensor([6.9693331718, 8.9492578506])
# Iter 553; theta =  tensor([6.9696311951, 8.9497251511])
# Iter 554; theta =  tensor([6.9699263573, 8.9501876831])
# Iter 555; theta =  tensor([6.9702186584, 8.9506464005])
# Iter 556; theta =  tensor([6.9705080986, 8.9511013031])
# Iter 557; theta =  tensor([6.9707946777, 8.9515514374])
# Iter 558; theta =  tensor([6.9710788727, 8.9519977570])
# Iter 559; theta =  tensor([6.9713602066, 8.9524402618])
# Iter 560; theta =  tensor([6.9716386795, 8.9528779984])
# Iter 561; theta =  tensor([6.9719142914, 8.9533119202])
# Iter 562; theta =  tensor([6.9721875191, 8.9537420273])
# Iter 563; theta =  tensor([6.9724578857, 8.9541683197])
# Iter 564; theta =  tensor([6.9727258682, 8.9545907974])
# Iter 565; theta =  tensor([6.9729909897, 8.9550094604])
# Iter 566; theta =  tensor([6.9732537270, 8.9554233551])
# Iter 567; theta =  tensor([6.9735136032, 8.9558334351])
# Iter 568; theta =  tensor([6.9737710953, 8.9562406540])
# Iter 569; theta =  tensor([6.9740262032, 8.9566440582])
# Iter 570; theta =  tensor([6.9742789268, 8.9570436478])
# Iter 571; theta =  tensor([6.9745287895, 8.9574394226])
# Iter 572; theta =  tensor([6.9747762680, 8.9578313828])
# Iter 573; theta =  tensor([6.9750213623, 8.9582195282])
# Iter 574; theta =  tensor([6.9752640724, 8.9586038589])
# Iter 575; theta =  tensor([6.9755043983, 8.9589853287])
# Iter 576; theta =  tensor([6.9757423401, 8.9593629837])
# Iter 577; theta =  tensor([6.9759778976, 8.9597368240])
# Iter 578; theta =  tensor([6.9762115479, 8.9601078033])
# Iter 579; theta =  tensor([6.9764428139, 8.9604749680])
# Iter 580; theta =  tensor([6.9766716957, 8.9608392715])
# Iter 581; theta =  tensor([6.9768986702, 8.9611997604])
# Iter 582; theta =  tensor([6.9771232605, 8.9615573883])
# Iter 583; theta =  tensor([6.9773454666, 8.9619112015])
# Iter 584; theta =  tensor([6.9775657654, 8.9622621536])
# Iter 585; theta =  tensor([6.9777836800, 8.9626092911])
# Iter 586; theta =  tensor([6.9779996872, 8.9629535675])
# Iter 587; theta =  tensor([6.9782133102, 8.9632949829])
# Iter 588; theta =  tensor([6.9784250259, 8.9636325836])
# Iter 589; theta =  tensor([6.9786348343, 8.9639673233])
# Iter 590; theta =  tensor([6.9788422585, 8.9642992020])
# Iter 591; theta =  tensor([6.9790477753, 8.9646282196])
# Iter 592; theta =  tensor([6.9792513847, 8.9649543762])
# Iter 593; theta =  tensor([6.9794530869, 8.9652767181])
# Iter 594; theta =  tensor([6.9796528816, 8.9655961990])
# Iter 595; theta =  tensor([6.9798507690, 8.9659128189])
# Iter 596; theta =  tensor([6.9800467491, 8.9662265778])
# Iter 597; theta =  tensor([6.9802408218, 8.9665374756])
# Iter 598; theta =  tensor([6.9804329872, 8.9668455124])
# Iter 599; theta =  tensor([6.9806232452, 8.9671506882])
# Iter 600; theta =  tensor([6.9808115959, 8.9674530029])
# Iter 601; theta =  tensor([6.9809980392, 8.9677524567])
# Iter 602; theta =  tensor([6.9811825752, 8.9680490494])
# Iter 603; theta =  tensor([6.9813652039, 8.9683437347])
# Iter 604; theta =  tensor([6.9815464020, 8.9686355591])
# Iter 605; theta =  tensor([6.9817256927, 8.9689245224])
# Iter 606; theta =  tensor([6.9819030762, 8.9692106247])
# Iter 607; theta =  tensor([6.9820790291, 8.9694938660])
# Iter 608; theta =  tensor([6.9822530746, 8.9697751999])
# Iter 609; theta =  tensor([6.9824256897, 8.9700536728])
# Iter 610; theta =  tensor([6.9825963974, 8.9703292847])
# Iter 611; theta =  tensor([6.9827656746, 8.9706029892])
# Iter 612; theta =  tensor([6.9829330444, 8.9708738327])
# Iter 613; theta =  tensor([6.9830989838, 8.9711418152])
# Iter 614; theta =  tensor([6.9832630157, 8.9714078903])
# Iter 615; theta =  tensor([6.9834256172, 8.9716711044])
# Iter 616; theta =  tensor([6.9835867882, 8.9719324112])
# Iter 617; theta =  tensor([6.9837460518, 8.9721908569])
# Iter 618; theta =  tensor([6.9839038849, 8.9724473953])
# Iter 619; theta =  tensor([6.9840602875, 8.9727010727])
# Iter 620; theta =  tensor([6.9842152596, 8.9729528427])
# Iter 621; theta =  tensor([6.9843688011, 8.9732017517])
# Iter 622; theta =  tensor([6.9845204353, 8.9734487534])
# Iter 623; theta =  tensor([6.9846706390, 8.9736928940])
# Iter 624; theta =  tensor([6.9848194122, 8.9739351273])
# Iter 625; theta =  tensor([6.9849667549, 8.9741754532])
# Iter 626; theta =  tensor([6.9851126671, 8.9744129181])
# Iter 627; theta =  tensor([6.9852571487, 8.9746484756])
# Iter 628; theta =  tensor([6.9854001999, 8.9748821259])
# Iter 629; theta =  tensor([6.9855418205, 8.9751138687])
# Iter 630; theta =  tensor([6.9856820107, 8.9753427505])
# Iter 631; theta =  tensor([6.9858212471, 8.9755697250])
# Iter 632; theta =  tensor([6.9859590530, 8.9757947922])
# Iter 633; theta =  tensor([6.9860954285, 8.9760179520])
# Iter 634; theta =  tensor([6.9862303734, 8.9762392044])
# Iter 635; theta =  tensor([6.9863638878, 8.9764585495])
# Iter 636; theta =  tensor([6.9864964485, 8.9766750336])
# Iter 637; theta =  tensor([6.9866275787, 8.9768896103])
# Iter 638; theta =  tensor([6.9867572784, 8.9771022797])
# Iter 639; theta =  tensor([6.9868860245, 8.9773130417])
# Iter 640; theta =  tensor([6.9870133400, 8.9775218964])
# Iter 641; theta =  tensor([6.9871392250, 8.9777288437])
# Iter 642; theta =  tensor([6.9872641563, 8.9779338837])
# Iter 643; theta =  tensor([6.9873876572, 8.9781370163])
# Iter 644; theta =  tensor([6.9875102043, 8.9783382416])
# Iter 645; theta =  tensor([6.9876313210, 8.9785375595])
# Iter 646; theta =  tensor([6.9877514839, 8.9787349701])
# Iter 647; theta =  tensor([6.9878702164, 8.9789304733])
# Iter 648; theta =  tensor([6.9879879951, 8.9791250229])
# Iter 649; theta =  tensor([6.9881048203, 8.9793176651])
# Iter 650; theta =  tensor([6.9882202148, 8.9795084000])

# %%
theta
# Out:
# tensor([-1.4229353458, -2.0863288759,  0.6736912836], dtype=torch.float64,
#        requires_grad=True)

# %% [markdown]
# 12. Altere a função de Gradiente Descendente para funcionar com minibatches. Em outras palavras, não compute o erro usando todos os dados de X. Use um `slice` de tamanho do minibatch. Uma ideia é seguir o pseudocódigo abaixo.
#
# ```python
# index = np.arange(len(X))
# while True:
#     minib = np.random.choice(index, minibatchsize) # aqui estou usando numpy para selection minibatch elementos
#     X_batch = X[minib]
# ```

# %%
# Exemplo abaixo
index = np.arange(len(X))
mb = np.random.choice(index, 50)
print(mb)
X[mb]
# Out:
# [  5 366   7 182   2 941 451 129 143   4 335 706 679 803 712  71 942   1
#   95 935 708 520 891 214  87 809 592 654  84 121 331 889 971 112 769  46
#  295 969 108 308 782 496 246 955 270 184 600 371 735 832]
# tensor([[ 1.0000000000, -0.9527182579],
#         [ 1.0000000000,  0.0122659942],
#         [ 1.0000000000, -1.4069408178],
#         [ 1.0000000000, -1.5737811327],
#         [ 1.0000000000, -0.1712963134],
#         [ 1.0000000000, -1.2470487356],
#         [ 1.0000000000,  0.2986788452],
#         [ 1.0000000000, -1.1483569145],
#         [ 1.0000000000,  1.6016647816],
#         [ 1.0000000000,  0.6885295510],
#         [ 1.0000000000,  0.0977276713],
#         [ 1.0000000000, -0.3735643327],
#         [ 1.0000000000,  0.9638742208],
#         [ 1.0000000000, -0.6083391309],
#         [ 1.0000000000,  0.9331179261],
#         [ 1.0000000000,  0.2381811589],
#         [ 1.0000000000, -0.7010558248],
#         [ 1.0000000000,  0.0356972478],
#         [ 1.0000000000, -0.1170007065],
#         [ 1.0000000000,  0.1933165938],
#         [ 1.0000000000,  0.0601990707],
#         [ 1.0000000000,  1.8448486328],
#         [ 1.0000000000, -0.5363392234],
#         [ 1.0000000000, -2.9743976593],
#         [ 1.0000000000, -0.2566402256],
#         [ 1.0000000000, -0.6144014597],
#         [ 1.0000000000, -0.6291584969],
#         [ 1.0000000000, -0.1753976196],
#         [ 1.0000000000, -0.3378271461],
#         [ 1.0000000000, -1.4263314009],
#         [ 1.0000000000, -0.4858186543],
#         [ 1.0000000000, -0.2312415391],
#         [ 1.0000000000, -0.0071473573],
#         [ 1.0000000000, -0.0783626959],
#         [ 1.0000000000,  1.2108789682],
#         [ 1.0000000000,  1.2170017958],
#         [ 1.0000000000, -0.1600404233],
#         [ 1.0000000000,  1.7290897369],
#         [ 1.0000000000, -1.1817331314],
#         [ 1.0000000000,  0.7653511167],
#         [ 1.0000000000, -0.5156726837],
#         [ 1.0000000000,  1.3546301126],
#         [ 1.0000000000,  0.8888308406],
#         [ 1.0000000000, -0.8244739175],
#         [ 1.0000000000,  0.3895377517],
#         [ 1.0000000000, -0.4501676261],
#         [ 1.0000000000, -0.7668770552],
#         [ 1.0000000000, -0.3156626523],
#         [ 1.0000000000, -0.9546895027],
#         [ 1.0000000000,  1.0053724051]])

# %%
def minibatch_gd(d_fun, loss_fun, X, y, lambda_=0.01, tol=0.00001,
                 max_iter=10000, batch_size=50):
    '''
    Executa Gradiente Descendente. Aqui:
    
    Parâmetros
    ----------
    d_fun : é uma função de derivadas
    loss_fun : é uma função de perda
    X : é um vetor de fatores explanatórios.
        Copie seu código de intercepto da primeira aula.
        para adicionar o intercepto em X.
    y : é a resposta
    lambda : é a taxa de aprendizad
    tol : é a tolerância, define quando o algoritmo vai parar.
    max_ter : é a segunda forma de parada, mesmo sem convergir
              paramos depois de max_iter iterações.
    batch_size : tamanho do batch
    '''
    theta = torch.randn(X.shape[1]).double()
    theta.requires_grad_(True)
    print('Iter {}; theta = '.format(0), theta)
    old_err_sq = np.inf
    i = 0
    
    index = np.arange(len(X))
    while True:
        theta.requires_grad_(True)
        # pega o mini batch
        mb = np.random.choice(index, batch_size)
        Xmb = X[mb]
        ymb = y[mb]
        
        # Computar as derivadas
        grad = d_fun(Xmb, theta, ymb)
        # Atualizar
        with torch.no_grad():
            theta_novo = theta - lambda_ * grad
        
        # Parar quando o erro convergir
        err_sq = loss_fun(Xmb, theta, ymb)
        if torch.abs(old_err_sq - err_sq) <= tol:
            break
        
        # Atualizar parâmetros e erro
        theta = theta_novo
        old_err_sq = err_sq
        
        # Informação de debug
        print('Iter {}; theta = '.format(i+1), theta)
        i += 1
        if i == max_iter:
            break
    return theta

# %%
# Sua função deve retornar algo perto de 7 e 9
minibatch_gd(derivada_torch, media_erros_quadrados, X, y)
# Out:
# Iter 0; theta =  tensor([-0.6153819561, -0.2942892313], dtype=torch.float64, requires_grad=True)
# Iter 1; theta =  tensor([-0.4600300694, -0.0917894602], dtype=torch.float64)
# Iter 2; theta =  tensor([-0.3006993580,  0.1137459898], dtype=torch.float64)
# Iter 3; theta =  tensor([-0.1599977016,  0.2849841642], dtype=torch.float64)
# Iter 4; theta =  tensor([-0.0273139286,  0.4122644663], dtype=torch.float64)
# Iter 5; theta =  tensor([0.0919956207, 0.5363367891], dtype=torch.float64)
# Iter 6; theta =  tensor([0.2266049862, 0.7172024393], dtype=torch.float64)
# Iter 7; theta =  tensor([0.3503619480, 0.8568773222], dtype=torch.float64)
# Iter 8; theta =  tensor([0.4854111290, 1.0187618399], dtype=torch.float64)
# Iter 9; theta =  tensor([0.6382602024, 1.2032831144], dtype=torch.float64)
# Iter 10; theta =  tensor([0.7424403954, 1.3337957525], dtype=torch.float64)
# Iter 11; theta =  tensor([0.8592113495, 1.4972277975], dtype=torch.float64)
# Iter 12; theta =  tensor([0.9676284122, 1.5989779997], dtype=torch.float64)
# Iter 13; theta =  tensor([1.0677062416, 1.7258811617], dtype=torch.float64)
# Iter 14; theta =  tensor([1.1750034809, 1.8165483522], dtype=torch.float64)
# Iter 15; theta =  tensor([1.3042644024, 1.9583136034], dtype=torch.float64)
# Iter 16; theta =  tensor([1.4088083458, 2.0845628405], dtype=torch.float64)
# Iter 17; theta =  tensor([1.5126180553, 2.2339811182], dtype=torch.float64)
# Iter 18; theta =  tensor([1.6370354366, 2.3719719172], dtype=torch.float64)
# Iter 19; theta =  tensor([1.7548907757, 2.5426357889], dtype=torch.float64)
# Iter 20; theta =  tensor([1.8710067844, 2.6751263857], dtype=torch.float64)
# Iter 21; theta =  tensor([1.9730247211, 2.7916865492], dtype=torch.float64)
# Iter 22; theta =  tensor([2.0731922436, 2.9120535612], dtype=torch.float64)
# Iter 23; theta =  tensor([2.1840016079, 3.0640992594], dtype=torch.float64)
# Iter 24; theta =  tensor([2.2655107975, 3.1293458748], dtype=torch.float64)
# Iter 25; theta =  tensor([2.3843502712, 3.2730968094], dtype=torch.float64)
# Iter 26; theta =  tensor([2.4846256161, 3.4361605644], dtype=torch.float64)
# Iter 27; theta =  tensor([2.5703574467, 3.5137383127], dtype=torch.float64)
# Iter 28; theta =  tensor([2.6657704067, 3.6122287226], dtype=torch.float64)
# Iter 29; theta =  tensor([2.7414095354, 3.6830772543], dtype=torch.float64)
# Iter 30; theta =  tensor([2.8297995424, 3.7758980131], dtype=torch.float64)
# Iter 31; theta =  tensor([2.9003633261, 3.8693125772], dtype=torch.float64)
# Iter 32; theta =  tensor([2.9978343058, 3.9753580236], dtype=torch.float64)
# Iter 33; theta =  tensor([3.0667426443, 4.0827890253], dtype=torch.float64)
# Iter 34; theta =  tensor([3.1367475224, 4.1687327528], dtype=torch.float64)
# Iter 35; theta =  tensor([3.2148213768, 4.2329681015], dtype=torch.float64)
# Iter 36; theta =  tensor([3.2796404457, 4.3223359776], dtype=torch.float64)
# Iter 37; theta =  tensor([3.3486106205, 4.4134446812], dtype=torch.float64)
# Iter 38; theta =  tensor([3.4270145988, 4.4773606491], dtype=torch.float64)
# Iter 39; theta =  tensor([3.5004938745, 4.5510086250], dtype=torch.float64)
# Iter 40; theta =  tensor([3.5835261679, 4.6661587143], dtype=torch.float64)
# Iter 41; theta =  tensor([3.6553466129, 4.7454055977], dtype=torch.float64)
# Iter 42; theta =  tensor([3.7101299953, 4.8074309301], dtype=torch.float64)
# Iter 43; theta =  tensor([3.7653600073, 4.8637224293], dtype=torch.float64)
# Iter 44; theta =  tensor([3.8363342953, 4.9170339918], dtype=torch.float64)
# Iter 45; theta =  tensor([3.9036503029, 4.9859491539], dtype=torch.float64)
# Iter 46; theta =  tensor([3.9620835209, 5.0554212046], dtype=torch.float64)
# Iter 47; theta =  tensor([4.0160108757, 5.1334033203], dtype=torch.float64)
# Iter 48; theta =  tensor([4.0822806597, 5.1907745790], dtype=torch.float64)
# Iter 49; theta =  tensor([4.1443790960, 5.2531137371], dtype=torch.float64)
# Iter 50; theta =  tensor([4.2096736765, 5.3564365673], dtype=torch.float64)
# Iter 51; theta =  tensor([4.2538815355, 5.4012771606], dtype=torch.float64)
# Iter 52; theta =  tensor([4.3189934111, 5.4497237158], dtype=torch.float64)
# Iter 53; theta =  tensor([4.3945985842, 5.5240746117], dtype=torch.float64)
# Iter 54; theta =  tensor([4.4362101507, 5.5739907408], dtype=torch.float64)
# Iter 55; theta =  tensor([4.4933066702, 5.6393583584], dtype=torch.float64)
# Iter 56; theta =  tensor([4.5485644960, 5.7031234694], dtype=torch.float64)
# Iter 57; theta =  tensor([4.6156058025, 5.7810375166], dtype=torch.float64)
# Iter 58; theta =  tensor([4.6655000019, 5.8595314312], dtype=torch.float64)
# Iter 59; theta =  tensor([4.7154466152, 5.9268979836], dtype=torch.float64)
# Iter 60; theta =  tensor([4.7545508671, 5.9603792334], dtype=torch.float64)
# Iter 61; theta =  tensor([4.7975727892, 6.0199409151], dtype=torch.float64)
# Iter 62; theta =  tensor([4.8399822378, 6.0764985847], dtype=torch.float64)
# Iter 63; theta =  tensor([4.8883582878, 6.1306950188], dtype=torch.float64)
# Iter 64; theta =  tensor([4.9242409325, 6.1963662720], dtype=torch.float64)
# Iter 65; theta =  tensor([4.9546565509, 6.2357995701], dtype=torch.float64)
# Iter 66; theta =  tensor([4.9957723784, 6.2778991461], dtype=torch.float64)
# Iter 67; theta =  tensor([5.0435832715, 6.3217528868], dtype=torch.float64)
# Iter 68; theta =  tensor([5.0872244573, 6.3656594467], dtype=torch.float64)
# Iter 69; theta =  tensor([5.1274973607, 6.4171222878], dtype=torch.float64)
# Iter 70; theta =  tensor([5.1619350076, 6.4534758520], dtype=torch.float64)
# Iter 71; theta =  tensor([5.2132803273, 6.5092968750], dtype=torch.float64)
# Iter 72; theta =  tensor([5.2482507825, 6.5638393402], dtype=torch.float64)
# Iter 73; theta =  tensor([5.2819935465, 6.6112295818], dtype=torch.float64)
# Iter 74; theta =  tensor([5.3111475110, 6.6415092373], dtype=torch.float64)
# Iter 75; theta =  tensor([5.3495308900, 6.6788685322], dtype=torch.float64)
# Iter 76; theta =  tensor([5.3831406927, 6.7041673756], dtype=torch.float64)
# Iter 77; theta =  tensor([5.4191373539, 6.7468798780], dtype=torch.float64)
# Iter 78; theta =  tensor([5.4415789223, 6.7958797312], dtype=torch.float64)
# Iter 79; theta =  tensor([5.4766857576, 6.8328247046], dtype=torch.float64)
# Iter 80; theta =  tensor([5.5052680826, 6.8570286131], dtype=torch.float64)
# Iter 81; theta =  tensor([5.5359979081, 6.8917189050], dtype=torch.float64)
# Iter 82; theta =  tensor([5.5602494168, 6.9199305010], dtype=torch.float64)
# Iter 83; theta =  tensor([5.5793233490, 6.9550728750], dtype=torch.float64)
# Iter 84; theta =  tensor([5.6024965048, 7.0128333950], dtype=torch.float64)
# Iter 85; theta =  tensor([5.6295968747, 7.0479807973], dtype=torch.float64)
# Iter 86; theta =  tensor([5.6504458046, 7.0785862780], dtype=torch.float64)
# Iter 87; theta =  tensor([5.6765846229, 7.1119947338], dtype=torch.float64)
# Iter 88; theta =  tensor([5.7094255972, 7.1533527660], dtype=torch.float64)
# Iter 89; theta =  tensor([5.7333890963, 7.1884382105], dtype=torch.float64)
# Iter 90; theta =  tensor([5.7550173283, 7.2098588610], dtype=torch.float64)
# Iter 91; theta =  tensor([5.7721171665, 7.2426128960], dtype=torch.float64)
# Iter 92; theta =  tensor([5.7873127270, 7.2736514974], dtype=torch.float64)
# Iter 93; theta =  tensor([5.8116778564, 7.3103941679], dtype=torch.float64)
# Iter 94; theta =  tensor([5.8373370290, 7.3356437397], dtype=torch.float64)
# Iter 95; theta =  tensor([5.8598578835, 7.3675701618], dtype=torch.float64)
# Iter 96; theta =  tensor([5.8731292689, 7.3935772991], dtype=torch.float64)
# Iter 97; theta =  tensor([5.8893813181, 7.4177480578], dtype=torch.float64)
# Iter 98; theta =  tensor([5.9151273513, 7.4460157442], dtype=torch.float64)
# Iter 99; theta =  tensor([5.9314358330, 7.4711165404], dtype=torch.float64)
# Iter 100; theta =  tensor([5.9481664944, 7.4951618361], dtype=torch.float64)
# Iter 101; theta =  tensor([5.9671514094, 7.5190057206], dtype=torch.float64)
# Iter 102; theta =  tensor([5.9863867307, 7.5434643650], dtype=torch.float64)
# Iter 103; theta =  tensor([6.0046576512, 7.5721843100], dtype=torch.float64)
# Iter 104; theta =  tensor([6.0268833697, 7.6016737723], dtype=torch.float64)
# Iter 105; theta =  tensor([6.0426099861, 7.6248337173], dtype=torch.float64)
# Iter 106; theta =  tensor([6.0597194338, 7.6613820410], dtype=torch.float64)
# Iter 107; theta =  tensor([6.0720612860, 7.6819493032], dtype=torch.float64)
# Iter 108; theta =  tensor([6.0920264411, 7.7192179871], dtype=torch.float64)
# Iter 109; theta =  tensor([6.1075536859, 7.7384278524], dtype=torch.float64)
# Iter 110; theta =  tensor([6.1233612370, 7.7606026590], dtype=torch.float64)
# Iter 111; theta =  tensor([6.1406696653, 7.7807159698], dtype=torch.float64)
# Iter 112; theta =  tensor([6.1581191969, 7.8055134761], dtype=torch.float64)
# Iter 113; theta =  tensor([6.1718032765, 7.8247346425], dtype=torch.float64)
# Iter 114; theta =  tensor([6.1910230255, 7.8465929937], dtype=torch.float64)
# Iter 115; theta =  tensor([6.2050455582, 7.8652725184], dtype=torch.float64)
# Iter 116; theta =  tensor([6.2258339655, 7.8878911293], dtype=torch.float64)
# Iter 117; theta =  tensor([6.2413003600, 7.9100688994], dtype=torch.float64)
# Iter 118; theta =  tensor([6.2592465520, 7.9288711214], dtype=torch.float64)
# Iter 119; theta =  tensor([6.2738258052, 7.9494602323], dtype=torch.float64)
# Iter 120; theta =  tensor([6.2935175228, 7.9713676572], dtype=torch.float64)
# Iter 121; theta =  tensor([6.3050863910, 7.9898396075], dtype=torch.float64)
# Iter 122; theta =  tensor([6.3187664366, 8.0220454729], dtype=torch.float64)
# Iter 123; theta =  tensor([6.3322524393, 8.0406979179], dtype=torch.float64)
# Iter 124; theta =  tensor([6.3471393716, 8.0544974303], dtype=torch.float64)
# Iter 125; theta =  tensor([6.3627860880, 8.0740233159], dtype=torch.float64)
# Iter 126; theta =  tensor([6.3773943615, 8.0947142935], dtype=torch.float64)
# Iter 127; theta =  tensor([6.3918137681, 8.1132319260], dtype=torch.float64)
# Iter 128; theta =  tensor([6.4029852343, 8.1230584335], dtype=torch.float64)
# Iter 129; theta =  tensor([6.4165408993, 8.1436220026], dtype=torch.float64)
# Iter 130; theta =  tensor([6.4239612383, 8.1618551731], dtype=torch.float64)
# Iter 131; theta =  tensor([6.4362114388, 8.1828955865], dtype=torch.float64)
# Iter 132; theta =  tensor([6.4471690780, 8.1978294909], dtype=torch.float64)
# Iter 133; theta =  tensor([6.4562728852, 8.2107403636], dtype=torch.float64)
# Iter 134; theta =  tensor([6.4616339171, 8.2248415160], dtype=torch.float64)
# Iter 135; theta =  tensor([6.4690903670, 8.2369263315], dtype=torch.float64)
# Iter 136; theta =  tensor([6.4808056229, 8.2518413162], dtype=torch.float64)
# Iter 137; theta =  tensor([6.4898613268, 8.2608171320], dtype=torch.float64)
# Iter 138; theta =  tensor([6.5003990513, 8.2734548843], dtype=torch.float64)
# Iter 139; theta =  tensor([6.5122215515, 8.2836211455], dtype=torch.float64)
# Iter 140; theta =  tensor([6.5200435776, 8.2940413892], dtype=torch.float64)
# Iter 141; theta =  tensor([6.5271579212, 8.3054110074], dtype=torch.float64)
# Iter 142; theta =  tensor([6.5327747220, 8.3150961274], dtype=torch.float64)
# Iter 143; theta =  tensor([6.5471929735, 8.3335708481], dtype=torch.float64)
# Iter 144; theta =  tensor([6.5540587586, 8.3460165364], dtype=torch.float64)
# Iter 145; theta =  tensor([6.5654885501, 8.3586628205], dtype=torch.float64)
# Iter 146; theta =  tensor([6.5742287529, 8.3724194950], dtype=torch.float64)
# Iter 147; theta =  tensor([6.5813680995, 8.3829024225], dtype=torch.float64)
# Iter 148; theta =  tensor([6.5899982405, 8.3972668380], dtype=torch.float64)
# Iter 149; theta =  tensor([6.5982180446, 8.4056958461], dtype=torch.float64)
# Iter 150; theta =  tensor([6.6041617531, 8.4159222090], dtype=torch.float64)
# Iter 151; theta =  tensor([6.6124193758, 8.4278071439], dtype=torch.float64)
# Iter 152; theta =  tensor([6.6233368081, 8.4411197591], dtype=torch.float64)
# Iter 153; theta =  tensor([6.6299089170, 8.4500635159], dtype=torch.float64)
# Iter 154; theta =  tensor([6.6390771854, 8.4597089899], dtype=torch.float64)
# Iter 155; theta =  tensor([6.6439019650, 8.4690478480], dtype=torch.float64)
# Iter 156; theta =  tensor([6.6500657403, 8.4795785713], dtype=torch.float64)
# Iter 157; theta =  tensor([6.6575396419, 8.4901287687], dtype=torch.float64)
# Iter 158; theta =  tensor([6.6656272089, 8.4986112386], dtype=torch.float64)
# Iter 159; theta =  tensor([6.6727114385, 8.5076271290], dtype=torch.float64)
# Iter 160; theta =  tensor([6.6787691993, 8.5151584435], dtype=torch.float64)
# Iter 161; theta =  tensor([6.6845762330, 8.5237550229], dtype=torch.float64)
# Iter 162; theta =  tensor([6.6892676118, 8.5316547334], dtype=torch.float64)
# Iter 163; theta =  tensor([6.6955367860, 8.5412352157], dtype=torch.float64)
# Iter 164; theta =  tensor([6.7010776076, 8.5498732495], dtype=torch.float64)
# Iter 165; theta =  tensor([6.7060989103, 8.5592247707], dtype=torch.float64)
# Iter 166; theta =  tensor([6.7123958591, 8.5719709605], dtype=torch.float64)
# Iter 167; theta =  tensor([6.7163676801, 8.5796006137], dtype=torch.float64)
# Iter 168; theta =  tensor([6.7219032153, 8.5873509663], dtype=torch.float64)
# Iter 169; theta =  tensor([6.7297457901, 8.5958612919], dtype=torch.float64)
# Iter 170; theta =  tensor([6.7337568444, 8.6034644264], dtype=torch.float64)
# Iter 171; theta =  tensor([6.7385311812, 8.6106687826], dtype=torch.float64)
# Iter 172; theta =  tensor([6.7435371727, 8.6171276152], dtype=torch.float64)
# Iter 173; theta =  tensor([6.7493283439, 8.6229935527], dtype=torch.float64)
# Iter 174; theta =  tensor([6.7543074554, 8.6298556471], dtype=torch.float64)
# Iter 175; theta =  tensor([6.7571627626, 8.6348627520], dtype=torch.float64)
# Iter 176; theta =  tensor([6.7637603644, 8.6434257334], dtype=torch.float64)
# Iter 177; theta =  tensor([6.7693981490, 8.6514091647], dtype=torch.float64)
# Iter 178; theta =  tensor([6.7723517579, 8.6584182644], dtype=torch.float64)
# Iter 179; theta =  tensor([6.7770445254, 8.6653723717], dtype=torch.float64)
# Iter 180; theta =  tensor([6.7804490602, 8.6714134800], dtype=torch.float64)
# Iter 181; theta =  tensor([6.7849494141, 8.6779573601], dtype=torch.float64)
# Iter 182; theta =  tensor([6.7904371089, 8.6863026547], dtype=torch.float64)
# Iter 183; theta =  tensor([6.7935851297, 8.6905310813], dtype=torch.float64)
# Iter 184; theta =  tensor([6.7976276052, 8.6950081593], dtype=torch.float64)
# Iter 185; theta =  tensor([6.8007288784, 8.7003406858], dtype=torch.float64)
# Iter 186; theta =  tensor([6.8059631145, 8.7050214994], dtype=torch.float64)
# Iter 187; theta =  tensor([6.8098730189, 8.7104334038], dtype=torch.float64)
# Iter 188; theta =  tensor([6.8127259251, 8.7143511432], dtype=torch.float64)
# Iter 189; theta =  tensor([6.8171409342, 8.7211630338], dtype=torch.float64)
# Iter 190; theta =  tensor([6.8211610028, 8.7266193002], dtype=torch.float64)
# Iter 191; theta =  tensor([6.8252281487, 8.7315228713], dtype=torch.float64)
# Iter 192; theta =  tensor([6.8287177426, 8.7355529982], dtype=torch.float64)
# Iter 193; theta =  tensor([6.8319811246, 8.7391746101], dtype=torch.float64)
# Iter 194; theta =  tensor([6.8358109912, 8.7443607149], dtype=torch.float64)
# Iter 195; theta =  tensor([6.8385191485, 8.7494758114], dtype=torch.float64)
# Iter 196; theta =  tensor([6.8428113979, 8.7555932239], dtype=torch.float64)
# Iter 197; theta =  tensor([6.8461254549, 8.7600534120], dtype=torch.float64)
# Iter 198; theta =  tensor([6.8498429638, 8.7639166135], dtype=torch.float64)
# Iter 199; theta =  tensor([6.8537804416, 8.7678616941], dtype=torch.float64)
# Iter 200; theta =  tensor([6.8559541440, 8.7708553043], dtype=torch.float64)
# Iter 201; theta =  tensor([6.8581489488, 8.7753993845], dtype=torch.float64)
# Iter 202; theta =  tensor([6.8609537405, 8.7790375620], dtype=torch.float64)
# Iter 203; theta =  tensor([6.8650092795, 8.7830010059], dtype=torch.float64)
# Iter 204; theta =  tensor([6.8673016010, 8.7861495361], dtype=torch.float64)
# Iter 205; theta =  tensor([6.8694030991, 8.7903277817], dtype=torch.float64)
# Iter 206; theta =  tensor([6.8724919128, 8.7947302961], dtype=torch.float64)
# Iter 207; theta =  tensor([6.8750421324, 8.7985067612], dtype=torch.float64)
# Iter 208; theta =  tensor([6.8779191160, 8.8018789884], dtype=torch.float64)
# Iter 209; theta =  tensor([6.8791117761, 8.8053403163], dtype=torch.float64)
# Iter 210; theta =  tensor([6.8815853548, 8.8087824801], dtype=torch.float64)
# Iter 211; theta =  tensor([6.8833003488, 8.8119457442], dtype=torch.float64)
# Iter 212; theta =  tensor([6.8855883665, 8.8144112062], dtype=torch.float64)
# Iter 213; theta =  tensor([6.8879848616, 8.8172453439], dtype=torch.float64)
# Iter 214; theta =  tensor([6.8897891808, 8.8208187827], dtype=torch.float64)
# Iter 215; theta =  tensor([6.8918748929, 8.8238247472], dtype=torch.float64)
# Iter 216; theta =  tensor([6.8941265380, 8.8275643334], dtype=torch.float64)
# Iter 217; theta =  tensor([6.8960309601, 8.8304578710], dtype=torch.float64)
# Iter 218; theta =  tensor([6.8987523475, 8.8328993422], dtype=torch.float64)
# Iter 219; theta =  tensor([6.9009761927, 8.8353668943], dtype=torch.float64)
# Iter 220; theta =  tensor([6.9040584287, 8.8401333591], dtype=torch.float64)
# Iter 221; theta =  tensor([6.9059536505, 8.8432407263], dtype=torch.float64)
# Iter 222; theta =  tensor([6.9078958321, 8.8466504291], dtype=torch.float64)
# Iter 223; theta =  tensor([6.9100541839, 8.8497181362], dtype=torch.float64)
# Iter 224; theta =  tensor([6.9120653355, 8.8531865180], dtype=torch.float64)
# Iter 225; theta =  tensor([6.9144373979, 8.8568496755], dtype=torch.float64)
# Iter 226; theta =  tensor([6.9153140542, 8.8589433046], dtype=torch.float64)
# Iter 227; theta =  tensor([6.9172327636, 8.8618702196], dtype=torch.float64)
# Iter 228; theta =  tensor([6.9182061133, 8.8642224643], dtype=torch.float64)
# Iter 229; theta =  tensor([6.9202652301, 8.8664666188], dtype=torch.float64)
# Iter 230; theta =  tensor([6.9217017907, 8.8691206890], dtype=torch.float64)
# Iter 231; theta =  tensor([6.9226768320, 8.8715052371], dtype=torch.float64)
# Iter 232; theta =  tensor([6.9240523425, 8.8737324864], dtype=torch.float64)
# Iter 233; theta =  tensor([6.9259977406, 8.8761241247], dtype=torch.float64)
# Iter 234; theta =  tensor([6.9273288222, 8.8787391563], dtype=torch.float64)
# Iter 235; theta =  tensor([6.9286654828, 8.8806048632], dtype=torch.float64)
# Iter 236; theta =  tensor([6.9299685333, 8.8826587442], dtype=torch.float64)
# Iter 237; theta =  tensor([6.9307897677, 8.8843678743], dtype=torch.float64)
# Iter 238; theta =  tensor([6.9320317469, 8.8861070924], dtype=torch.float64)
# Iter 239; theta =  tensor([6.9336835446, 8.8887036650], dtype=torch.float64)
# Iter 240; theta =  tensor([6.9347839717, 8.8908213988], dtype=torch.float64)
# Iter 241; theta =  tensor([6.9358628069, 8.8929177128], dtype=torch.float64)
# Iter 242; theta =  tensor([6.9371914570, 8.8946518424], dtype=torch.float64)
# Iter 243; theta =  tensor([6.9386712064, 8.8966827418], dtype=torch.float64)
# Iter 244; theta =  tensor([6.9398758867, 8.8988595329], dtype=torch.float64)
# Iter 245; theta =  tensor([6.9404359380, 8.8998941956], dtype=torch.float64)
# Iter 246; theta =  tensor([6.9413593715, 8.9017568240], dtype=torch.float64)
# Iter 247; theta =  tensor([6.9421248881, 8.9037398552], dtype=torch.float64)
# Iter 248; theta =  tensor([6.9432128860, 8.9049262074], dtype=torch.float64)
# Iter 249; theta =  tensor([6.9443877526, 8.9065384943], dtype=torch.float64)
# Iter 250; theta =  tensor([6.9456682947, 8.9086465653], dtype=torch.float64)
# Iter 251; theta =  tensor([6.9465695538, 8.9103521087], dtype=torch.float64)
# Iter 252; theta =  tensor([6.9473733902, 8.9119899093], dtype=torch.float64)
# Iter 253; theta =  tensor([6.9487306553, 8.9143784348], dtype=torch.float64)
# Iter 254; theta =  tensor([6.9500445749, 8.9162853875], dtype=torch.float64)
# Iter 255; theta =  tensor([6.9506874127, 8.9176888154], dtype=torch.float64)
# Iter 256; theta =  tensor([6.9515102935, 8.9190625601], dtype=torch.float64)
# Iter 257; theta =  tensor([6.9522541914, 8.9205563318], dtype=torch.float64)
# Iter 258; theta =  tensor([6.9530983576, 8.9216589966], dtype=torch.float64)
# Iter 259; theta =  tensor([6.9537253999, 8.9231130956], dtype=torch.float64)
# Iter 260; theta =  tensor([6.9543699902, 8.9245139678], dtype=torch.float64)
# Iter 261; theta =  tensor([6.9552105258, 8.9260476877], dtype=torch.float64)
# Iter 262; theta =  tensor([6.9559364154, 8.9274262390], dtype=torch.float64)
# Iter 263; theta =  tensor([6.9565101921, 8.9284278091], dtype=torch.float64)
# Iter 264; theta =  tensor([6.9570784062, 8.9296719731], dtype=torch.float64)
# Iter 265; theta =  tensor([6.9580624492, 8.9311359772], dtype=torch.float64)
# Iter 266; theta =  tensor([6.9587330609, 8.9322698247], dtype=torch.float64)
# Iter 267; theta =  tensor([6.9593554788, 8.9333980969], dtype=torch.float64)
# Iter 268; theta =  tensor([6.9602560376, 8.9350572339], dtype=torch.float64)
# Iter 269; theta =  tensor([6.9610803403, 8.9360866860], dtype=torch.float64)
# Iter 270; theta =  tensor([6.9617631209, 8.9374934471], dtype=torch.float64)
# Iter 271; theta =  tensor([6.9622283803, 8.9386893117], dtype=torch.float64)
# Iter 272; theta =  tensor([6.9630043477, 8.9397909141], dtype=torch.float64)
# Iter 273; theta =  tensor([6.9639118788, 8.9411742035], dtype=torch.float64)
# Iter 274; theta =  tensor([6.9647726000, 8.9424805924], dtype=torch.float64)
# Iter 275; theta =  tensor([6.9655213189, 8.9438294258], dtype=torch.float64)
# Iter 276; theta =  tensor([6.9662352976, 8.9444888250], dtype=torch.float64)
# Iter 277; theta =  tensor([6.9668877253, 8.9454701577], dtype=torch.float64)
# Iter 278; theta =  tensor([6.9675508923, 8.9465036020], dtype=torch.float64)
# Iter 279; theta =  tensor([6.9680809010, 8.9472662460], dtype=torch.float64)
# Iter 280; theta =  tensor([6.9687102935, 8.9485532407], dtype=torch.float64)
# Iter 281; theta =  tensor([6.9693419550, 8.9493624999], dtype=torch.float64)
# Iter 282; theta =  tensor([6.9699314221, 8.9502368600], dtype=torch.float64)
# Iter 283; theta =  tensor([6.9705939671, 8.9513902971], dtype=torch.float64)
# Iter 284; theta =  tensor([6.9710720946, 8.9523646183], dtype=torch.float64)
# Iter 285; theta =  tensor([6.9715864349, 8.9532024846], dtype=torch.float64)
# Iter 286; theta =  tensor([6.9721843575, 8.9537739757], dtype=torch.float64)
# Iter 287; theta =  tensor([6.9728786590, 8.9550175793], dtype=torch.float64)
# Iter 288; theta =  tensor([6.9734184008, 8.9557119691], dtype=torch.float64)
# Iter 289; theta =  tensor([6.9738927634, 8.9565274874], dtype=torch.float64)
# Iter 290; theta =  tensor([6.9742961547, 8.9572074284], dtype=torch.float64)
# Iter 291; theta =  tensor([6.9749396889, 8.9582225005], dtype=torch.float64)
# Iter 292; theta =  tensor([6.9755031110, 8.9589937586], dtype=torch.float64)
# Iter 293; theta =  tensor([6.9759568000, 8.9598160993], dtype=torch.float64)
# Iter 294; theta =  tensor([6.9764093949, 8.9605070567], dtype=torch.float64)
# Iter 295; theta =  tensor([6.9768327685, 8.9611061822], dtype=torch.float64)
# Iter 296; theta =  tensor([6.9773601063, 8.9617319332], dtype=torch.float64)
# Iter 297; theta =  tensor([6.9778683089, 8.9623263021], dtype=torch.float64)
# Iter 298; theta =  tensor([6.9783840505, 8.9629804627], dtype=torch.float64)
# Iter 299; theta =  tensor([6.9787935585, 8.9635445695], dtype=torch.float64)
# Iter 300; theta =  tensor([6.9791494042, 8.9641813939], dtype=torch.float64)
# Iter 301; theta =  tensor([6.9795089107, 8.9647537648], dtype=torch.float64)
# Iter 302; theta =  tensor([6.9800313233, 8.9654554628], dtype=torch.float64)
# Iter 303; theta =  tensor([6.9803507905, 8.9660829651], dtype=torch.float64)
# Iter 304; theta =  tensor([6.9808803604, 8.9668377052], dtype=torch.float64)
# Iter 305; theta =  tensor([6.9813339179, 8.9676170989], dtype=torch.float64)
# Iter 306; theta =  tensor([6.9816922640, 8.9680748212], dtype=torch.float64)
# Iter 307; theta =  tensor([6.9820325337, 8.9688950834], dtype=torch.float64)
# Iter 308; theta =  tensor([6.9824279953, 8.9694139510], dtype=torch.float64)
# Iter 309; theta =  tensor([6.9828140591, 8.9701184678], dtype=torch.float64)
# Iter 310; theta =  tensor([6.9832437511, 8.9707452975], dtype=torch.float64)
# Iter 311; theta =  tensor([6.9834483379, 8.9712345320], dtype=torch.float64)
# Iter 312; theta =  tensor([6.9837117655, 8.9717789471], dtype=torch.float64)
# Iter 313; theta =  tensor([6.9840775930, 8.9723590576], dtype=torch.float64)
# Iter 314; theta =  tensor([6.9842170931, 8.9728840752], dtype=torch.float64)
# Iter 315; theta =  tensor([6.9844238238, 8.9733193298], dtype=torch.float64)
# Iter 316; theta =  tensor([6.9847624513, 8.9738303900], dtype=torch.float64)
# Iter 317; theta =  tensor([6.9849821251, 8.9743636749], dtype=torch.float64)
# Iter 318; theta =  tensor([6.9853376890, 8.9748836156], dtype=torch.float64)
# Iter 319; theta =  tensor([6.9856205897, 8.9754375492], dtype=torch.float64)
# Iter 320; theta =  tensor([6.9859258967, 8.9759025653], dtype=torch.float64)
# Iter 321; theta =  tensor([6.9861890410, 8.9763221438], dtype=torch.float64)
# Iter 322; theta =  tensor([6.9865729141, 8.9768788958], dtype=torch.float64)
# Iter 323; theta =  tensor([6.9868432477, 8.9774110067], dtype=torch.float64)
# Iter 324; theta =  tensor([6.9870728508, 8.9777699893], dtype=torch.float64)
# Iter 325; theta =  tensor([6.9872722373, 8.9780543323], dtype=torch.float64)
# Iter 326; theta =  tensor([6.9874707104, 8.9784549831], dtype=torch.float64)
# Iter 327; theta =  tensor([6.9877959067, 8.9788564931], dtype=torch.float64)
# Iter 328; theta =  tensor([6.9880814961, 8.9794165093], dtype=torch.float64)
# Iter 329; theta =  tensor([6.9883986135, 8.9798020392], dtype=torch.float64)
# Iter 330; theta =  tensor([6.9885849943, 8.9800544792], dtype=torch.float64)
# Iter 331; theta =  tensor([6.9887883115, 8.9803870499], dtype=torch.float64)
# Iter 332; theta =  tensor([6.9891296864, 8.9809686098], dtype=torch.float64)
# Iter 333; theta =  tensor([6.9893096729, 8.9814365620], dtype=torch.float64)
# Iter 334; theta =  tensor([6.9894401472, 8.9818102158], dtype=torch.float64)
# Iter 335; theta =  tensor([6.9896127456, 8.9821424728], dtype=torch.float64)
# Iter 336; theta =  tensor([6.9898363572, 8.9824213830], dtype=torch.float64)
# Iter 337; theta =  tensor([6.9900306796, 8.9828164895], dtype=torch.float64)
# Iter 338; theta =  tensor([6.9901957464, 8.9830703438], dtype=torch.float64)
# Iter 339; theta =  tensor([6.9903410652, 8.9833238419], dtype=torch.float64)
# Iter 340; theta =  tensor([6.9905458369, 8.9836779799], dtype=torch.float64)
# Iter 341; theta =  tensor([6.9907129749, 8.9839991398], dtype=torch.float64)
# Iter 342; theta =  tensor([6.9908904369, 8.9844091698], dtype=torch.float64)
# Iter 343; theta =  tensor([6.9910563680, 8.9846307341], dtype=torch.float64)
# Iter 344; theta =  tensor([6.9912321021, 8.9849700586], dtype=torch.float64)
# tensor([6.9912321021, 8.9849700586], dtype=torch.float64, requires_grad=True)

# %% [markdown]
# ## Conjunto de Problemas 3: Logistic from Scratch

# %% [markdown]
# 12. Repita o mesmo processo para a Logística. Lembrando que a mesma tem a seguinte forma:
#
# $$f(x_i) = \frac{1}{1 + e^{-(1 + \theta_1 x_{i1} + \theta_2 x_{i2} + \cdots \theta_k x_{ik})}}$$
#
# Implemente a função logística.

# %%
def logistic(X, theta):
    return 1.0 / (1 + torch.exp(-torch.matmul(X, theta)))

# %%
# testes, não apague!
X_teste = torch.randn(1000, 20000)
theta = torch.randn(20000)
y_hat_teste = logistic(X_teste, theta)
assert_equal(True, (y_hat_teste >= 0).numpy().all())
assert_equal(True, (y_hat_teste <= 1).numpy().all())

# %% [markdown]
# Usando a logística acima implemente uma função logistica_prever que retorna 0 ou 1. Use o limiar dado na função.

# %%
def logistica_prever(X, theta, limiar=0.5):
    return logistic(X, theta) > limiar

# %%
# testes, não apague!
X_teste = torch.randn(1000, 20000)
theta = torch.randn(20000)
y_hat_teste = logistica_prever(X_teste, theta)
for yi in y_hat_teste.numpy():
    assert(yi in {0, 1})

# %% [markdown]
# Agora, implemente uma função de entropia cruzada da logística. A mesma, é proporcional ao inverso da verossimilhança. Para entender a derivação entre as duas faça uso dos [Slides](https://docs.google.com/presentation/d/1yGPETPe8o7PPOP6_CF38LHr3vpxgTEnF5LjP-1pkGIc/edit?usp=sharing).
#
# Sendo:
#
# $$ll(x_i,y_i~|~\theta) = y_i \log f(x_i\theta) + (1-y_i) \log (1-f(x_i\theta))$$
#
# A verossimilhança para uma observação. A entropia cruzada é a media da negação do termo para todos os exemplos:
#
# $$L(\theta) = -n^{-1}\sum_i \big((1-y_i)\log (1-f_{\theta}(x_i)) + y_i\log (f_{\theta}(x_i))\big)$$
#
# `dica: use torch.clamp(logistic(X, theta), min = 0.001, max = 0.999)`. A função remove os 0 e 1s da logistic, evitando assim o valor log(0).

# %%
def cross_entropy_mean(X, theta, y):
    logit = logistic(X, theta)
    logit = torch.clamp(logit, min=0.00001, max = 0.99999)
    return -(y * torch.log(logit) + (1 - y) * torch.log(1 - logit)).mean()

# %%
# testes, não apague!
from sklearn import datasets
state = np.random.seed(20190187)

X, y = datasets.make_blobs(n_samples=200, n_features=2, centers=2)
X = torch.tensor(X).double()
y = torch.tensor(y).double()

for _ in range(100):
    theta = torch.randn(2,1).double()
    assert(cross_entropy_mean(X, theta, y) >= 0)

# %% [markdown]
# Agora implemente a derivada.

# %%
def derivada_torch_logit(X, theta, y):
    e = cross_entropy_mean(X, theta, y)
    e.backward()
    return theta.grad

# %% [markdown]
# A partir daqui basta executar código.

# %%
plt.scatter(X.numpy()[:, 0], X.numpy()[:, 1], s=80, edgecolors='k')

# %% [markdown]
# 13. Assim como foi feito na primeira aula, abaixo testamos o seu código com um toy dataset.

# %%
# Use essa função antes de executar o GD
def add_intercept(X):
    Xn = torch.zeros(X.shape[0], X.shape[1] + 1).double()
    Xn[:, 0]  = 1.0
    Xn[:, 1:] = X
    return Xn

# %%
Xn = add_intercept(X)
theta = minibatch_gd(derivada_torch_logit, cross_entropy_mean, Xn, y)
# Out:
# Iter 0; theta =  tensor([-0.8224458694,  2.0350472927, -0.7380897403], dtype=torch.float64,
#        requires_grad=True)
# Iter 1; theta =  tensor([-0.8226462231,  2.0136114850, -0.6971920511], dtype=torch.float64)
# Iter 2; theta =  tensor([-0.8222472916,  1.9901040957, -0.6492418288], dtype=torch.float64)
# Iter 3; theta =  tensor([-0.8210508434,  1.9672959206, -0.5958474717], dtype=torch.float64)
# Iter 4; theta =  tensor([-0.8204576029,  1.9445267000, -0.5458375697], dtype=torch.float64)
# Iter 5; theta =  tensor([-0.8188636552,  1.9255096894, -0.4962364085], dtype=torch.float64)
# Iter 6; theta =  tensor([-0.8182697129,  1.9005597132, -0.4444700938], dtype=torch.float64)
# Iter 7; theta =  tensor([-0.8186961483,  1.8741617075, -0.3960888280], dtype=torch.float64)
# Iter 8; theta =  tensor([-0.8171435722,  1.8525727662, -0.3399968730], dtype=torch.float64)
# Iter 9; theta =  tensor([-0.8159824794,  1.8276096131, -0.2839070762], dtype=torch.float64)
# Iter 10; theta =  tensor([-0.8139348641,  1.8070276216, -0.2274877114], dtype=torch.float64)
# Iter 11; theta =  tensor([-0.8145150335,  1.7791739595, -0.1797719874], dtype=torch.float64)
# Iter 12; theta =  tensor([-0.8153553832,  1.7505577883, -0.1327699335], dtype=torch.float64)
# Iter 13; theta =  tensor([-0.8144247021,  1.7254092111, -0.0755261186], dtype=torch.float64)
# Iter 14; theta =  tensor([-0.8170625583,  1.6939422291, -0.0367701713], dtype=torch.float64)
# Iter 15; theta =  tensor([-0.8188966722,  1.6627758070,  0.0058024769], dtype=torch.float64)
# Iter 16; theta =  tensor([-0.8185048011,  1.6372907461,  0.0535576247], dtype=torch.float64)
# Iter 17; theta =  tensor([-0.8204922731,  1.6071143352,  0.0915353336], dtype=torch.float64)
# Iter 18; theta =  tensor([-0.8208384752,  1.5818957310,  0.1339887553], dtype=torch.float64)
# Iter 19; theta =  tensor([-0.8232396155,  1.5528692251,  0.1655632174], dtype=torch.float64)
# Iter 20; theta =  tensor([-0.8265957742,  1.5188888148,  0.1976207729], dtype=torch.float64)
# Iter 21; theta =  tensor([-0.8286101942,  1.4913147639,  0.2295358303], dtype=torch.float64)
# Iter 22; theta =  tensor([-0.8310243224,  1.4609711441,  0.2603816342], dtype=torch.float64)
# Iter 23; theta =  tensor([-0.8333151879,  1.4337071087,  0.2902758098], dtype=torch.float64)
# Iter 24; theta =  tensor([-0.8366592852,  1.4065713679,  0.3112554544], dtype=torch.float64)
# Iter 25; theta =  tensor([-0.8397824567,  1.3824157951,  0.3300353089], dtype=torch.float64)
# Iter 26; theta =  tensor([-0.8417188325,  1.3622273832,  0.3497934093], dtype=torch.float64)
# Iter 27; theta =  tensor([-0.8461120522,  1.3353606542,  0.3650055216], dtype=torch.float64)
# Iter 28; theta =  tensor([-0.8501214232,  1.3089953235,  0.3798425005], dtype=torch.float64)
# Iter 29; theta =  tensor([-0.8541387567,  1.2828628119,  0.3955874436], dtype=torch.float64)
# Iter 30; theta =  tensor([-0.8582500436,  1.2594371924,  0.4078650014], dtype=torch.float64)
# Iter 31; theta =  tensor([-0.8633723352,  1.2287934735,  0.4199250302], dtype=torch.float64)
# Iter 32; theta =  tensor([-0.8665135024,  1.2084154781,  0.4329579425], dtype=torch.float64)
# Iter 33; theta =  tensor([-0.8700070735,  1.1841426255,  0.4453045400], dtype=torch.float64)
# Iter 34; theta =  tensor([-0.8748396817,  1.1560558921,  0.4555786261], dtype=torch.float64)
# Iter 35; theta =  tensor([-0.8792564878,  1.1302543588,  0.4657998922], dtype=torch.float64)
# Iter 36; theta =  tensor([-0.8838237323,  1.1055213096,  0.4758316295], dtype=torch.float64)
# Iter 37; theta =  tensor([-0.8869023618,  1.0869439725,  0.4847650223], dtype=torch.float64)
# Iter 38; theta =  tensor([-0.8912610161,  1.0611876425,  0.4940094895], dtype=torch.float64)
# Iter 39; theta =  tensor([-0.8961353887,  1.0328002326,  0.5059286751], dtype=torch.float64)
# Iter 40; theta =  tensor([-0.9012771819,  1.0048302731,  0.5145388147], dtype=torch.float64)
# Iter 41; theta =  tensor([-0.9061994711,  0.9769270027,  0.5243752061], dtype=torch.float64)
# Iter 42; theta =  tensor([-0.9085318716,  0.9638388738,  0.5315262506], dtype=torch.float64)
# Iter 43; theta =  tensor([-0.9117123966,  0.9442605080,  0.5405102958], dtype=torch.float64)
# Iter 44; theta =  tensor([-0.9163195988,  0.9193152533,  0.5499237307], dtype=torch.float64)
# Iter 45; theta =  tensor([-0.9209365802,  0.8956644987,  0.5580661338], dtype=torch.float64)
# Iter 46; theta =  tensor([-0.9254652032,  0.8712740166,  0.5642969090], dtype=torch.float64)
# Iter 47; theta =  tensor([-0.9297684676,  0.8476610481,  0.5708478920], dtype=torch.float64)
# Iter 48; theta =  tensor([-0.9343228715,  0.8242881336,  0.5795468216], dtype=torch.float64)
# Iter 49; theta =  tensor([-0.9389961561,  0.8005878506,  0.5860346191], dtype=torch.float64)
# Iter 50; theta =  tensor([-0.9429591214,  0.7778922419,  0.5918799177], dtype=torch.float64)
# Iter 51; theta =  tensor([-0.9459087493,  0.7618400185,  0.5970661647], dtype=torch.float64)
# Iter 52; theta =  tensor([-0.9507064976,  0.7371769619,  0.6027527871], dtype=torch.float64)
# Iter 53; theta =  tensor([-0.9548071917,  0.7153704522,  0.6091335384], dtype=torch.float64)
# Iter 54; theta =  tensor([-0.9590491978,  0.6926271095,  0.6156333406], dtype=torch.float64)
# Iter 55; theta =  tensor([-0.9624739394,  0.6747778336,  0.6217890644], dtype=torch.float64)
# Iter 56; theta =  tensor([-0.9669419022,  0.6506927810,  0.6274507180], dtype=torch.float64)
# Iter 57; theta =  tensor([-0.9706363037,  0.6307745653,  0.6319299149], dtype=torch.float64)
# Iter 58; theta =  tensor([-0.9745000938,  0.6087879780,  0.6367631008], dtype=torch.float64)
# Iter 59; theta =  tensor([-0.9783706551,  0.5881988557,  0.6417214718], dtype=torch.float64)
# Iter 60; theta =  tensor([-0.9819961149,  0.5686081813,  0.6474922456], dtype=torch.float64)
# Iter 61; theta =  tensor([-0.9860601142,  0.5462985861,  0.6529002266], dtype=torch.float64)
# Iter 62; theta =  tensor([-0.9893691863,  0.5276226255,  0.6575700439], dtype=torch.float64)
# Iter 63; theta =  tensor([-0.9920351735,  0.5128310691,  0.6616337396], dtype=torch.float64)
# Iter 64; theta =  tensor([-0.9959143110,  0.4931237177,  0.6649298650], dtype=torch.float64)
# Iter 65; theta =  tensor([-0.9994879850,  0.4753314593,  0.6689600356], dtype=torch.float64)
# Iter 66; theta =  tensor([-1.0028697067,  0.4571151421,  0.6731960317], dtype=torch.float64)
# Iter 67; theta =  tensor([-1.0051530348,  0.4456334734,  0.6756785300], dtype=torch.float64)
# Iter 68; theta =  tensor([-1.0083713567,  0.4287466393,  0.6790627465], dtype=torch.float64)
# Iter 69; theta =  tensor([-1.0110742057,  0.4139869419,  0.6822741385], dtype=torch.float64)
# Iter 70; theta =  tensor([-1.0135766539,  0.4005912519,  0.6853461408], dtype=torch.float64)
# Iter 71; theta =  tensor([-1.0161097533,  0.3863263999,  0.6885136708], dtype=torch.float64)
# Iter 72; theta =  tensor([-1.0184053676,  0.3738390666,  0.6911615595], dtype=torch.float64)
# Iter 73; theta =  tensor([-1.0205143155,  0.3631186860,  0.6939016599], dtype=torch.float64)
# Iter 74; theta =  tensor([-1.0227194677,  0.3516311087,  0.6966546660], dtype=torch.float64)
# Iter 75; theta =  tensor([-1.0251194576,  0.3387086335,  0.7000752576], dtype=torch.float64)
# Iter 76; theta =  tensor([-1.0273178200,  0.3278050703,  0.7022683204], dtype=torch.float64)
# Iter 77; theta =  tensor([-1.0301037994,  0.3131143230,  0.7049584973], dtype=torch.float64)
# Iter 78; theta =  tensor([-1.0323343302,  0.3021747428,  0.7073487504], dtype=torch.float64)
# Iter 79; theta =  tensor([-1.0341790722,  0.2926227410,  0.7090777568], dtype=torch.float64)
# Iter 80; theta =  tensor([-1.0362901772,  0.2808843071,  0.7118403866], dtype=torch.float64)
# Iter 81; theta =  tensor([-1.0385073576,  0.2696259575,  0.7135836148], dtype=torch.float64)
# Iter 82; theta =  tensor([-1.0407392287,  0.2577083700,  0.7153202698], dtype=torch.float64)
# Iter 83; theta =  tensor([-1.0433019740,  0.2448074114,  0.7167696576], dtype=torch.float64)
# Iter 84; theta =  tensor([-1.0449801144,  0.2362436582,  0.7187637070], dtype=torch.float64)
# Iter 85; theta =  tensor([-1.0465841723,  0.2273384454,  0.7195876925], dtype=torch.float64)
# Iter 86; theta =  tensor([-1.0483896599,  0.2176481361,  0.7214960882], dtype=torch.float64)
# Iter 87; theta =  tensor([-1.0502333507,  0.2083185108,  0.7231461639], dtype=torch.float64)
# Iter 88; theta =  tensor([-1.0523236986,  0.1978926724,  0.7240845156], dtype=torch.float64)
# Iter 89; theta =  tensor([-1.0537511125,  0.1907629055,  0.7257586635], dtype=torch.float64)
# Iter 90; theta =  tensor([-1.0552389314,  0.1829038456,  0.7269454943], dtype=torch.float64)
# Iter 91; theta =  tensor([-1.0565049568,  0.1770037796,  0.7279711501], dtype=torch.float64)
# Iter 92; theta =  tensor([-1.0578698969,  0.1695347177,  0.7290028638], dtype=torch.float64)
# Iter 93; theta =  tensor([-1.0588991299,  0.1638008326,  0.7303138569], dtype=torch.float64)
# Iter 94; theta =  tensor([-1.0607062276,  0.1542530550,  0.7319359252], dtype=torch.float64)
# Iter 95; theta =  tensor([-1.0621138354,  0.1464517474,  0.7330882972], dtype=torch.float64)
# Iter 96; theta =  tensor([-1.0635270322,  0.1392047993,  0.7343398378], dtype=torch.float64)
# Iter 97; theta =  tensor([-1.0647751638,  0.1328748112,  0.7355623571], dtype=torch.float64)
# Iter 98; theta =  tensor([-1.0660590889,  0.1267318297,  0.7361906225], dtype=torch.float64)
# Iter 99; theta =  tensor([-1.0672825939,  0.1204199227,  0.7372893270], dtype=torch.float64)
# Iter 100; theta =  tensor([-1.0680816630,  0.1163226399,  0.7381770845], dtype=torch.float64)
# Iter 101; theta =  tensor([-1.0689058808,  0.1118595007,  0.7392365461], dtype=torch.float64)
# Iter 102; theta =  tensor([-1.0701218960,  0.1055597805,  0.7400871636], dtype=torch.float64)
# Iter 103; theta =  tensor([-1.0713447264,  0.0990794717,  0.7412694690], dtype=torch.float64)
# Iter 104; theta =  tensor([-1.0720861245,  0.0948356591,  0.7421438119], dtype=torch.float64)
# Iter 105; theta =  tensor([-1.0729039713,  0.0905227439,  0.7429895929], dtype=torch.float64)
# Iter 106; theta =  tensor([-1.0742232832,  0.0838807986,  0.7435750868], dtype=torch.float64)
# Iter 107; theta =  tensor([-1.0748744399,  0.0803653697,  0.7442551478], dtype=torch.float64)
# Iter 108; theta =  tensor([-1.0758363574,  0.0755209564,  0.7453599504], dtype=torch.float64)
# Iter 109; theta =  tensor([-1.0765596713,  0.0718588055,  0.7461586344], dtype=torch.float64)
# Iter 110; theta =  tensor([-1.0772977251,  0.0682136256,  0.7469988747], dtype=torch.float64)
# Iter 111; theta =  tensor([-1.0785299291,  0.0615440099,  0.7479120846], dtype=torch.float64)
# Iter 112; theta =  tensor([-1.0794107825,  0.0568947566,  0.7486753907], dtype=torch.float64)
# Iter 113; theta =  tensor([-1.0800748544,  0.0533788971,  0.7493872171], dtype=torch.float64)
# Iter 114; theta =  tensor([-1.0812804314,  0.0476825491,  0.7502492395], dtype=torch.float64)
# Iter 115; theta =  tensor([-1.0820130572,  0.0438459879,  0.7511480761], dtype=torch.float64)
# Iter 116; theta =  tensor([-1.0825854403,  0.0409431171,  0.7518463564], dtype=torch.float64)
# Iter 117; theta =  tensor([-1.0832646153,  0.0375241952,  0.7526547214], dtype=torch.float64)
# Iter 118; theta =  tensor([-1.0841249313,  0.0331770592,  0.7533601782], dtype=torch.float64)
# Iter 119; theta =  tensor([-1.0846835496,  0.0302289172,  0.7540680937], dtype=torch.float64)
# Iter 120; theta =  tensor([-1.0854658536,  0.0260427914,  0.7546582982], dtype=torch.float64)
# Iter 121; theta =  tensor([-1.0862703555,  0.0220340602,  0.7553449942], dtype=torch.float64)
# Iter 122; theta =  tensor([-1.0869432896,  0.0185738748,  0.7560701609], dtype=torch.float64)
# Iter 123; theta =  tensor([-1.0876616996,  0.0149290201,  0.7567857173], dtype=torch.float64)
# Iter 124; theta =  tensor([-1.0883908431,  0.0110822183,  0.7574646934], dtype=torch.float64)
# Iter 125; theta =  tensor([-1.0892651702,  0.0067511695,  0.7580893974], dtype=torch.float64)
# Iter 126; theta =  tensor([-1.0897978727,  0.0039254837,  0.7588701387], dtype=torch.float64)
# Iter 127; theta =  tensor([-1.0904403523e+00,  5.0555264576e-04,  7.5969124127e-01],
#        dtype=torch.float64)
# Iter 128; theta =  tensor([-1.0911731735, -0.0026393721,  0.7602735687], dtype=torch.float64)
# Iter 129; theta =  tensor([-1.0918302936, -0.0062178577,  0.7608787646], dtype=torch.float64)
# Iter 130; theta =  tensor([-1.0923468298, -0.0090681944,  0.7616140360], dtype=torch.float64)
# Iter 131; theta =  tensor([-1.0932051520, -0.0130687324,  0.7619533156], dtype=torch.float64)
# Iter 132; theta =  tensor([-1.0938737558, -0.0164095984,  0.7624556877], dtype=torch.float64)
# Iter 133; theta =  tensor([-1.0947723538, -0.0207842574,  0.7629384080], dtype=torch.float64)
# Iter 134; theta =  tensor([-1.0953408411, -0.0238963838,  0.7636283050], dtype=torch.float64)
# Iter 135; theta =  tensor([-1.0960508880, -0.0271332881,  0.7640657174], dtype=torch.float64)
# Iter 136; theta =  tensor([-1.0967099955, -0.0304171237,  0.7644110577], dtype=torch.float64)
# Iter 137; theta =  tensor([-1.0973246478, -0.0334088155,  0.7647456238], dtype=torch.float64)
# Iter 138; theta =  tensor([-1.0981133457, -0.0376440985,  0.7650788602], dtype=torch.float64)
# Iter 139; theta =  tensor([-1.0988798451, -0.0414818112,  0.7656017674], dtype=torch.float64)
# Iter 140; theta =  tensor([-1.0992929461, -0.0436357827,  0.7660417468], dtype=torch.float64)
# Iter 141; theta =  tensor([-1.0999609599, -0.0471831395,  0.7665988014], dtype=torch.float64)
# Iter 142; theta =  tensor([-1.1007523897, -0.0511656101,  0.7668881831], dtype=torch.float64)
# Iter 143; theta =  tensor([-1.1012830219, -0.0539447579,  0.7674161472], dtype=torch.float64)
# Iter 144; theta =  tensor([-1.1018648139, -0.0570010449,  0.7678662582], dtype=torch.float64)
# Iter 145; theta =  tensor([-1.1023792312, -0.0595034108,  0.7684365153], dtype=torch.float64)
# Iter 146; theta =  tensor([-1.1028436020, -0.0619941052,  0.7689678482], dtype=torch.float64)
# Iter 147; theta =  tensor([-1.1032513218, -0.0642564490,  0.7694632274], dtype=torch.float64)
# Iter 148; theta =  tensor([-1.1037543830, -0.0668342515,  0.7698355613], dtype=torch.float64)
# Iter 149; theta =  tensor([-1.1042795799, -0.0694997448,  0.7702613564], dtype=torch.float64)
# Iter 150; theta =  tensor([-1.1046859052, -0.0714869363,  0.7707042667], dtype=torch.float64)
# Iter 151; theta =  tensor([-1.1052680709, -0.0742662268,  0.7709932560], dtype=torch.float64)
# Iter 152; theta =  tensor([-1.1059066594, -0.0773535476,  0.7713364672], dtype=torch.float64)
# Iter 153; theta =  tensor([-1.1065400948, -0.0807493178,  0.7716651264], dtype=torch.float64)
# Iter 154; theta =  tensor([-1.1070518640, -0.0833871911,  0.7720882318], dtype=torch.float64)
# Iter 155; theta =  tensor([-1.1076200289, -0.0862084202,  0.7725189268], dtype=torch.float64)
# Iter 156; theta =  tensor([-1.1080144673, -0.0882751564,  0.7729610692], dtype=torch.float64)
# Iter 157; theta =  tensor([-1.1084163330, -0.0902552789,  0.7733050508], dtype=torch.float64)
# Iter 158; theta =  tensor([-1.1089887923, -0.0931939439,  0.7736101353], dtype=torch.float64)
# Iter 159; theta =  tensor([-1.1094274067, -0.0954779288,  0.7741834984], dtype=torch.float64)
# Iter 160; theta =  tensor([-1.1098599486, -0.0977484624,  0.7745960915], dtype=torch.float64)
# Iter 161; theta =  tensor([-1.1101685497, -0.0994588098,  0.7750330789], dtype=torch.float64)
# Iter 162; theta =  tensor([-1.1106504004, -0.1016464114,  0.7752716791], dtype=torch.float64)
# Iter 163; theta =  tensor([-1.1111317946, -0.1038266780,  0.7756497125], dtype=torch.float64)
# Iter 164; theta =  tensor([-1.1115838758, -0.1061004313,  0.7759960291], dtype=torch.float64)
# Iter 165; theta =  tensor([-1.1120009644, -0.1083420208,  0.7764806528], dtype=torch.float64)
# Iter 166; theta =  tensor([-1.1125472062, -0.1110077558,  0.7766828608], dtype=torch.float64)
# Iter 167; theta =  tensor([-1.1130878283, -0.1139892821,  0.7771403421], dtype=torch.float64)
# Iter 168; theta =  tensor([-1.1135846805, -0.1165940791,  0.7774326452], dtype=torch.float64)
# Iter 169; theta =  tensor([-1.1140041593, -0.1187046373,  0.7777599268], dtype=torch.float64)
# Iter 170; theta =  tensor([-1.1144212205, -0.1206990825,  0.7782012992], dtype=torch.float64)
# Iter 171; theta =  tensor([-1.1147743723, -0.1224852003,  0.7786577570], dtype=torch.float64)
# Iter 172; theta =  tensor([-1.1151999764, -0.1246708320,  0.7789830869], dtype=torch.float64)
# Iter 173; theta =  tensor([-1.1156601407, -0.1269469621,  0.7793288330], dtype=torch.float64)
# Iter 174; theta =  tensor([-1.1160052561, -0.1287521476,  0.7797512824], dtype=torch.float64)
# Iter 175; theta =  tensor([-1.1163709894, -0.1305857182,  0.7801078682], dtype=torch.float64)
# Iter 176; theta =  tensor([-1.1168039631, -0.1327922641,  0.7804815226], dtype=torch.float64)
# Iter 177; theta =  tensor([-1.1171817182, -0.1348688212,  0.7808306349], dtype=torch.float64)
# Iter 178; theta =  tensor([-1.1175714930, -0.1365999419,  0.7811343747], dtype=torch.float64)
# Iter 179; theta =  tensor([-1.1179614893, -0.1384159411,  0.7815242010], dtype=torch.float64)
# Iter 180; theta =  tensor([-1.1182801279, -0.1401166707,  0.7818447712], dtype=torch.float64)
# Iter 181; theta =  tensor([-1.1186799704, -0.1421094729,  0.7821633265], dtype=torch.float64)
# Iter 182; theta =  tensor([-1.1191108113, -0.1443676810,  0.7824507160], dtype=torch.float64)
# Iter 183; theta =  tensor([-1.1194368684, -0.1460397076,  0.7827844541], dtype=torch.float64)
# Iter 184; theta =  tensor([-1.1200101905, -0.1487154073,  0.7828923356], dtype=torch.float64)
# Iter 185; theta =  tensor([-1.1203418681, -0.1502928351,  0.7832372175], dtype=torch.float64)
# Iter 186; theta =  tensor([-1.1206470242, -0.1519083104,  0.7835671794], dtype=torch.float64)
# Iter 187; theta =  tensor([-1.1210033733, -0.1536233958,  0.7838601329], dtype=torch.float64)
# Iter 188; theta =  tensor([-1.1213034280, -0.1552255477,  0.7842071477], dtype=torch.float64)
# Iter 189; theta =  tensor([-1.1215793302, -0.1567024428,  0.7845288843], dtype=torch.float64)
# Iter 190; theta =  tensor([-1.1217822063, -0.1577925436,  0.7847689008], dtype=torch.float64)
# Iter 191; theta =  tensor([-1.1221894058, -0.1596969035,  0.7849102515], dtype=torch.float64)
# Iter 192; theta =  tensor([-1.1225249142, -0.1613076086,  0.7852047064], dtype=torch.float64)
# Iter 193; theta =  tensor([-1.1228833641, -0.1632933981,  0.7855563829], dtype=torch.float64)
# Iter 194; theta =  tensor([-1.1231967798, -0.1650170119,  0.7859476245], dtype=torch.float64)
# Iter 195; theta =  tensor([-1.1235459569, -0.1666963147,  0.7862356839], dtype=torch.float64)
# Iter 196; theta =  tensor([-1.1239515764, -0.1686778586,  0.7864567464], dtype=torch.float64)
# Iter 197; theta =  tensor([-1.1242139024, -0.1699290725,  0.7867442179], dtype=torch.float64)
# Iter 198; theta =  tensor([-1.1245616866, -0.1716117757,  0.7871156534], dtype=torch.float64)
# Iter 199; theta =  tensor([-1.1247908750, -0.1728259480,  0.7874831600], dtype=torch.float64)
# Iter 200; theta =  tensor([-1.1251487684, -0.1745717822,  0.7876385728], dtype=torch.float64)
# Iter 201; theta =  tensor([-1.1254450089, -0.1761046813,  0.7879591733], dtype=torch.float64)
# Iter 202; theta =  tensor([-1.1256182167, -0.1769559131,  0.7882144321], dtype=torch.float64)
# Iter 203; theta =  tensor([-1.1259215789, -0.1784459114,  0.7884816255], dtype=torch.float64)
# Iter 204; theta =  tensor([-1.1261270345, -0.1795073422,  0.7887130764], dtype=torch.float64)
# Iter 205; theta =  tensor([-1.1263680878, -0.1808079327,  0.7890066182], dtype=torch.float64)
# Iter 206; theta =  tensor([-1.1266430317, -0.1821738478,  0.7891971793], dtype=torch.float64)
# Iter 207; theta =  tensor([-1.1270308251, -0.1840984224,  0.7895051242], dtype=torch.float64)
# Iter 208; theta =  tensor([-1.1273389002, -0.1856711970,  0.7897133613], dtype=torch.float64)
# Iter 209; theta =  tensor([-1.1278635648, -0.1880880918,  0.7898580606], dtype=torch.float64)
# Iter 210; theta =  tensor([-1.1281885232, -0.1897562806,  0.7901108100], dtype=torch.float64)
# Iter 211; theta =  tensor([-1.1283898687, -0.1907221342,  0.7904397707], dtype=torch.float64)
# Iter 212; theta =  tensor([-1.1286657234, -0.1921947920,  0.7906913294], dtype=torch.float64)
# Iter 213; theta =  tensor([-1.1289704360, -0.1936789253,  0.7909921259], dtype=torch.float64)
# Iter 214; theta =  tensor([-1.1292069229, -0.1949055375,  0.7913094294], dtype=torch.float64)
# Iter 215; theta =  tensor([-1.1294477867, -0.1960581911,  0.7915678829], dtype=torch.float64)
# Iter 216; theta =  tensor([-1.1297126215, -0.1974190475,  0.7918324489], dtype=torch.float64)
# Iter 217; theta =  tensor([-1.1300062782, -0.1988784762,  0.7920220952], dtype=torch.float64)
# Iter 218; theta =  tensor([-1.1303191592, -0.2004767952,  0.7922537974], dtype=torch.float64)
# Iter 219; theta =  tensor([-1.1305665730, -0.2017693611,  0.7925478235], dtype=torch.float64)
# Iter 220; theta =  tensor([-1.1309849544, -0.2037857738,  0.7926674570], dtype=torch.float64)
# Iter 221; theta =  tensor([-1.1312000427, -0.2048904348,  0.7929572772], dtype=torch.float64)
# Iter 222; theta =  tensor([-1.1313834926, -0.2058438407,  0.7931849841], dtype=torch.float64)
# Iter 223; theta =  tensor([-1.1316509485, -0.2071532299,  0.7933361227], dtype=torch.float64)
# Iter 224; theta =  tensor([-1.1319322406, -0.2085904027,  0.7936084390], dtype=torch.float64)
# Iter 225; theta =  tensor([-1.1320745718, -0.2093995595,  0.7938954006], dtype=torch.float64)
# Iter 226; theta =  tensor([-1.1323001617, -0.2105107054,  0.7941202349], dtype=torch.float64)
# Iter 227; theta =  tensor([-1.1325277285, -0.2116235410,  0.7944050679], dtype=torch.float64)
# Iter 228; theta =  tensor([-1.1327998772, -0.2130104931,  0.7946074488], dtype=torch.float64)
# Iter 229; theta =  tensor([-1.1329861745, -0.2139585511,  0.7948331360], dtype=torch.float64)
# Iter 230; theta =  tensor([-1.1331614565, -0.2148953425,  0.7951109616], dtype=torch.float64)
# Iter 231; theta =  tensor([-1.1333171562, -0.2157564094,  0.7953834923], dtype=torch.float64)
# Iter 232; theta =  tensor([-1.1336153156, -0.2171728689,  0.7955862899], dtype=torch.float64)
# Iter 233; theta =  tensor([-1.1337991198, -0.2181066501,  0.7957941886], dtype=torch.float64)
# Iter 234; theta =  tensor([-1.1339959990, -0.2191789146,  0.7960444252], dtype=torch.float64)
# Iter 235; theta =  tensor([-1.1341722794, -0.2200725441,  0.7962881066], dtype=torch.float64)
# Iter 236; theta =  tensor([-1.1344564397, -0.2214205448,  0.7964007297], dtype=torch.float64)
# Iter 237; theta =  tensor([-1.1346622579, -0.2224705902,  0.7966630907], dtype=torch.float64)
# Iter 238; theta =  tensor([-1.1349167215, -0.2237682951,  0.7969085266], dtype=torch.float64)
# Iter 239; theta =  tensor([-1.1350971521, -0.2247445938,  0.7970580763], dtype=torch.float64)
# Iter 240; theta =  tensor([-1.1352301610, -0.2254528090,  0.7972869576], dtype=torch.float64)
# Iter 241; theta =  tensor([-1.1354510436, -0.2265812071,  0.7974974559], dtype=torch.float64)
# Iter 242; theta =  tensor([-1.1357895904, -0.2281703013,  0.7975483244], dtype=torch.float64)
# Iter 243; theta =  tensor([-1.1360267198, -0.2293916625,  0.7978133753], dtype=torch.float64)
# Iter 244; theta =  tensor([-1.1363727889, -0.2310021088,  0.7978902944], dtype=torch.float64)
# Iter 245; theta =  tensor([-1.1367077420, -0.2326056189,  0.7981360082], dtype=torch.float64)
# Iter 246; theta =  tensor([-1.1369238985, -0.2336962629,  0.7984162683], dtype=torch.float64)
# Iter 247; theta =  tensor([-1.1371927489, -0.2351272954,  0.7986737004], dtype=torch.float64)
# Iter 248; theta =  tensor([-1.1373781221, -0.2360969973,  0.7989387586], dtype=torch.float64)
# Iter 249; theta =  tensor([-1.1375370602, -0.2370184143,  0.7991706639], dtype=torch.float64)
# Iter 250; theta =  tensor([-1.1376717085, -0.2377257682,  0.7994042613], dtype=torch.float64)
# Iter 251; theta =  tensor([-1.1379556291, -0.2390746114,  0.7996424735], dtype=torch.float64)
# Iter 252; theta =  tensor([-1.1381969855, -0.2403147737,  0.7998996727], dtype=torch.float64)
# Iter 253; theta =  tensor([-1.1384321279, -0.2415227574,  0.8001340292], dtype=torch.float64)
# Iter 254; theta =  tensor([-1.1387184433, -0.2429172048,  0.8002639302], dtype=torch.float64)
# Iter 255; theta =  tensor([-1.1389153418, -0.2438733449,  0.8005047146], dtype=torch.float64)
# Iter 256; theta =  tensor([-1.1391767129, -0.2450918329,  0.8005961789], dtype=torch.float64)
# Iter 257; theta =  tensor([-1.1394162536, -0.2463045205,  0.8008207718], dtype=torch.float64)
# Iter 258; theta =  tensor([-1.1395931001, -0.2471580034,  0.8009848430], dtype=torch.float64)
# Iter 259; theta =  tensor([-1.1398078427, -0.2481891336,  0.8012111861], dtype=torch.float64)
# Iter 260; theta =  tensor([-1.1400428826, -0.2493669660,  0.8014689483], dtype=torch.float64)
# Iter 261; theta =  tensor([-1.1402754000, -0.2505649825,  0.8016774348], dtype=torch.float64)
# Iter 262; theta =  tensor([-1.1404539765, -0.2514576427,  0.8019462732], dtype=torch.float64)
# Iter 263; theta =  tensor([-1.1406640976, -0.2525331491,  0.8021310124], dtype=torch.float64)
# Iter 264; theta =  tensor([-1.1408450113, -0.2534422346,  0.8023134658], dtype=torch.float64)
# Iter 265; theta =  tensor([-1.1410757773, -0.2545590216,  0.8025500186], dtype=torch.float64)
# Iter 266; theta =  tensor([-1.1413069694, -0.2556419513,  0.8026847333], dtype=torch.float64)
# Iter 267; theta =  tensor([-1.1415340851, -0.2568325500,  0.8028849964], dtype=torch.float64)
# Iter 268; theta =  tensor([-1.1417741761, -0.2580647117,  0.8031360700], dtype=torch.float64)
# Iter 269; theta =  tensor([-1.1419391870, -0.2589377430,  0.8033738687], dtype=torch.float64)
# Iter 270; theta =  tensor([-1.1421618315, -0.2599483181,  0.8035918363], dtype=torch.float64)
# Iter 271; theta =  tensor([-1.1424010532, -0.2611589005,  0.8037915962], dtype=torch.float64)
# Iter 272; theta =  tensor([-1.1426168879, -0.2622414651,  0.8039689505], dtype=torch.float64)
# Iter 273; theta =  tensor([-1.1427680841, -0.2630306420,  0.8042219169], dtype=torch.float64)
# Iter 274; theta =  tensor([-1.1429527799, -0.2639520046,  0.8044822347], dtype=torch.float64)
# Iter 275; theta =  tensor([-1.1431190599, -0.2648090541,  0.8046375720], dtype=torch.float64)
# Iter 276; theta =  tensor([-1.1433183366, -0.2657821351,  0.8048664858], dtype=torch.float64)
# Iter 277; theta =  tensor([-1.1435614531, -0.2669291917,  0.8049757193], dtype=torch.float64)
# Iter 278; theta =  tensor([-1.1437445972, -0.2678255655,  0.8051345807], dtype=torch.float64)
# Iter 279; theta =  tensor([-1.1439578382, -0.2688297186,  0.8052822235], dtype=torch.float64)
# Iter 280; theta =  tensor([-1.1441899695, -0.2699619858,  0.8054410073], dtype=torch.float64)
# Iter 281; theta =  tensor([-1.1443446423, -0.2706879701,  0.8056251525], dtype=torch.float64)
# Iter 282; theta =  tensor([-1.1445471929, -0.2717565316,  0.8057797795], dtype=torch.float64)
# Iter 283; theta =  tensor([-1.1447148865, -0.2726005447,  0.8060271821], dtype=torch.float64)
# Iter 284; theta =  tensor([-1.1448800240, -0.2734411826,  0.8062285814], dtype=torch.float64)
# Iter 285; theta =  tensor([-1.1450098130, -0.2740842837,  0.8064190538], dtype=torch.float64)
# Iter 286; theta =  tensor([-1.1451973343, -0.2750777480,  0.8065707675], dtype=torch.float64)
# Iter 287; theta =  tensor([-1.1454480431, -0.2762213357,  0.8066490847], dtype=torch.float64)
# Iter 288; theta =  tensor([-1.1457195238, -0.2774694450,  0.8067329369], dtype=torch.float64)
# Iter 289; theta =  tensor([-1.1459408529, -0.2785595060,  0.8069100825], dtype=torch.float64)
# Iter 290; theta =  tensor([-1.1461250242, -0.2794360928,  0.8070772350], dtype=torch.float64)
# Iter 291; theta =  tensor([-1.1462053891, -0.2798793096,  0.8072639249], dtype=torch.float64)
# Iter 292; theta =  tensor([-1.1464341370, -0.2810501821,  0.8074640393], dtype=torch.float64)
# Iter 293; theta =  tensor([-1.1466219159, -0.2820620448,  0.8076276526], dtype=torch.float64)
# Iter 294; theta =  tensor([-1.1468443609, -0.2831420030,  0.8077469289], dtype=torch.float64)
# Iter 295; theta =  tensor([-1.1470576514, -0.2842050100,  0.8079029726], dtype=torch.float64)
# Iter 296; theta =  tensor([-1.1472276801, -0.2850382201,  0.8081232264], dtype=torch.float64)
# Iter 297; theta =  tensor([-1.1473682440, -0.2857151135,  0.8083199213], dtype=torch.float64)
# Iter 298; theta =  tensor([-1.1475459491, -0.2866351261,  0.8085335733], dtype=torch.float64)
# Iter 299; theta =  tensor([-1.1477828682, -0.2877414673,  0.8086566971], dtype=torch.float64)
# Iter 300; theta =  tensor([-1.1479085212, -0.2884422675,  0.8088635502], dtype=torch.float64)
# Iter 301; theta =  tensor([-1.1480670879, -0.2892444873,  0.8090558131], dtype=torch.float64)
# Iter 302; theta =  tensor([-1.1482958833, -0.2903421197,  0.8092129990], dtype=torch.float64)
# Iter 303; theta =  tensor([-1.1484854693, -0.2913019887,  0.8093341844], dtype=torch.float64)
# Iter 304; theta =  tensor([-1.1486197903, -0.2919836582,  0.8094903207], dtype=torch.float64)
# Iter 305; theta =  tensor([-1.1488402117, -0.2930133167,  0.8096852392], dtype=torch.float64)
# Iter 306; theta =  tensor([-1.1490980188, -0.2942383539,  0.8098372821], dtype=torch.float64)
# Iter 307; theta =  tensor([-1.1492724456, -0.2951076549,  0.8100078895], dtype=torch.float64)
# Iter 308; theta =  tensor([-1.1494617674, -0.2959808557,  0.8101488380], dtype=torch.float64)
# Iter 309; theta =  tensor([-1.1495377352, -0.2964176128,  0.8103405170], dtype=torch.float64)
# Iter 310; theta =  tensor([-1.1497166877, -0.2972216810,  0.8104855321], dtype=torch.float64)
# Iter 311; theta =  tensor([-1.1499489255, -0.2982931185,  0.8106438086], dtype=torch.float64)
# Iter 312; theta =  tensor([-1.1500664421, -0.2989580361,  0.8108459681], dtype=torch.float64)
# Iter 313; theta =  tensor([-1.1502613442, -0.2999116131,  0.8109657804], dtype=torch.float64)
# Iter 314; theta =  tensor([-1.1505188752, -0.3011346934,  0.8110271640], dtype=torch.float64)
# Iter 315; theta =  tensor([-1.1506582985, -0.3018098170,  0.8111814218], dtype=torch.float64)
# Iter 316; theta =  tensor([-1.1508058622, -0.3025643423,  0.8113890081], dtype=torch.float64)
# Iter 317; theta =  tensor([-1.1509283066, -0.3032220570,  0.8116067925], dtype=torch.float64)
# Iter 318; theta =  tensor([-1.1510970534, -0.3040717250,  0.8117733461], dtype=torch.float64)
# Iter 319; theta =  tensor([-1.1512251268, -0.3047162573,  0.8119465597], dtype=torch.float64)
# Iter 320; theta =  tensor([-1.1513723620, -0.3054101645,  0.8121015641], dtype=torch.float64)
# Iter 321; theta =  tensor([-1.1515232061, -0.3061620206,  0.8122541197], dtype=torch.float64)
# Iter 322; theta =  tensor([-1.1516487802, -0.3068437675,  0.8124338066], dtype=torch.float64)
# Iter 323; theta =  tensor([-1.1519047176, -0.3080607550,  0.8125234974], dtype=torch.float64)
# Iter 324; theta =  tensor([-1.1520209999, -0.3086909037,  0.8126804658], dtype=torch.float64)
# Iter 325; theta =  tensor([-1.1521900124, -0.3095297235,  0.8128622673], dtype=torch.float64)
# Iter 326; theta =  tensor([-1.1523496387, -0.3103766727,  0.8129967595], dtype=torch.float64)
# Iter 327; theta =  tensor([-1.1525010173, -0.3111669511,  0.8131516839], dtype=torch.float64)
# Iter 328; theta =  tensor([-1.1527029301, -0.3121095515,  0.8132542994], dtype=torch.float64)
# Iter 329; theta =  tensor([-1.1529075013, -0.3131098942,  0.8133711364], dtype=torch.float64)
# Iter 330; theta =  tensor([-1.1530730814, -0.3139027374,  0.8135413610], dtype=torch.float64)
# Iter 331; theta =  tensor([-1.1531830056, -0.3145179343,  0.8137420971], dtype=torch.float64)
# Iter 332; theta =  tensor([-1.1533190845, -0.3152128855,  0.8139118855], dtype=torch.float64)
# Iter 333; theta =  tensor([-1.1535254687, -0.3162274491,  0.8139393869], dtype=torch.float64)
# Iter 334; theta =  tensor([-1.1536777069, -0.3169756408,  0.8140965377], dtype=torch.float64)
# Iter 335; theta =  tensor([-1.1538376774, -0.3177964920,  0.8142516396], dtype=torch.float64)
# Iter 336; theta =  tensor([-1.1539615023, -0.3184595675,  0.8144455592], dtype=torch.float64)
# Iter 337; theta =  tensor([-1.1541082274, -0.3192115534,  0.8146354985], dtype=torch.float64)
# Iter 338; theta =  tensor([-1.1542580208, -0.3199585418,  0.8148126341], dtype=torch.float64)
# Iter 339; theta =  tensor([-1.1544048874, -0.3206682906,  0.8149813912], dtype=torch.float64)
# Iter 340; theta =  tensor([-1.1545616438, -0.3214523828,  0.8150826566], dtype=torch.float64)
# Iter 341; theta =  tensor([-1.1547418584, -0.3223531253,  0.8152748630], dtype=torch.float64)
# Iter 342; theta =  tensor([-1.1548588515, -0.3229877796,  0.8154620713], dtype=torch.float64)
# Iter 343; theta =  tensor([-1.1550297339, -0.3238840204,  0.8155765234], dtype=torch.float64)
# Iter 344; theta =  tensor([-1.1551252584, -0.3244560107,  0.8157810707], dtype=torch.float64)
# Iter 345; theta =  tensor([-1.1552225422, -0.3249500073,  0.8159405682], dtype=torch.float64)
# Iter 346; theta =  tensor([-1.1553457054, -0.3256064844,  0.8160975848], dtype=torch.float64)
# Iter 347; theta =  tensor([-1.1554646123, -0.3262203655,  0.8162690230], dtype=torch.float64)
# Iter 348; theta =  tensor([-1.1555470511, -0.3266721172,  0.8164340446], dtype=torch.float64)
# Iter 349; theta =  tensor([-1.1556840407, -0.3273440439,  0.8165846453], dtype=torch.float64)
# Iter 350; theta =  tensor([-1.1558401226, -0.3280577344,  0.8166413777], dtype=torch.float64)
# Iter 351; theta =  tensor([-1.1559639475, -0.3287195302,  0.8168101030], dtype=torch.float64)
# Iter 352; theta =  tensor([-1.1561080164, -0.3294815906,  0.8169481837], dtype=torch.float64)
# Iter 353; theta =  tensor([-1.1562072541, -0.3300040855,  0.8170991842], dtype=torch.float64)
# Iter 354; theta =  tensor([-1.1564155206, -0.3309856622,  0.8171840489], dtype=torch.float64)
# Iter 355; theta =  tensor([-1.1565960889, -0.3318492991,  0.8173916428], dtype=torch.float64)
# Iter 356; theta =  tensor([-1.1567387515, -0.3325967605,  0.8175520771], dtype=torch.float64)
# Iter 357; theta =  tensor([-1.1568893541, -0.3333554963,  0.8177407032], dtype=torch.float64)
# Iter 358; theta =  tensor([-1.1570600521, -0.3342207590,  0.8178339158], dtype=torch.float64)
# Iter 359; theta =  tensor([-1.1571792673, -0.3348394446,  0.8180028751], dtype=torch.float64)
# Iter 360; theta =  tensor([-1.1572846072, -0.3353263936,  0.8181944105], dtype=torch.float64)
# Iter 361; theta =  tensor([-1.1574055722, -0.3359958438,  0.8183823354], dtype=torch.float64)
# Iter 362; theta =  tensor([-1.1575464530, -0.3366763228,  0.8185103294], dtype=torch.float64)
# Iter 363; theta =  tensor([-1.1577531955, -0.3376654253,  0.8186257734], dtype=torch.float64)
# Iter 364; theta =  tensor([-1.1578803174, -0.3383232036,  0.8187661435], dtype=torch.float64)
# Iter 365; theta =  tensor([-1.1579845761, -0.3388545063,  0.8189114202], dtype=torch.float64)
# Iter 366; theta =  tensor([-1.1581227798, -0.3396084855,  0.8190603330], dtype=torch.float64)
# Iter 367; theta =  tensor([-1.1582157495, -0.3401339956,  0.8192323913], dtype=torch.float64)
# Iter 368; theta =  tensor([-1.1583565143, -0.3408494749,  0.8193778445], dtype=torch.float64)
# Iter 369; theta =  tensor([-1.1585033200, -0.3415382278,  0.8195357624], dtype=torch.float64)
# Iter 370; theta =  tensor([-1.1586905220, -0.3424199252,  0.8196606184], dtype=torch.float64)
# Iter 371; theta =  tensor([-1.1588547764, -0.3432105535,  0.8197948799], dtype=torch.float64)
# Iter 372; theta =  tensor([-1.1589826269, -0.3438272952,  0.8199431069], dtype=torch.float64)
# Iter 373; theta =  tensor([-1.1591257558, -0.3444982483,  0.8201588526], dtype=torch.float64)
# Iter 374; theta =  tensor([-1.1592157944, -0.3449760659,  0.8203259957], dtype=torch.float64)
# Iter 375; theta =  tensor([-1.1593672153, -0.3457357474,  0.8204228705], dtype=torch.float64)
# Iter 376; theta =  tensor([-1.1594650413, -0.3462810020,  0.8206062591], dtype=torch.float64)
# Iter 377; theta =  tensor([-1.1595794568, -0.3468833353,  0.8207643680], dtype=torch.float64)
# Iter 378; theta =  tensor([-1.1597540477, -0.3477507765,  0.8208677671], dtype=torch.float64)
# Iter 379; theta =  tensor([-1.1598677032, -0.3483581325,  0.8210291228], dtype=torch.float64)
# Iter 380; theta =  tensor([-1.1599613208, -0.3488458133,  0.8211573597], dtype=torch.float64)
# Iter 381; theta =  tensor([-1.1600974854, -0.3495433624,  0.8213159884], dtype=torch.float64)
# Iter 382; theta =  tensor([-1.1602137256, -0.3501358919,  0.8214695129], dtype=torch.float64)
# Iter 383; theta =  tensor([-1.1602888315, -0.3505286473,  0.8216653244], dtype=torch.float64)
# Iter 384; theta =  tensor([-1.1604227920, -0.3511884350,  0.8218043511], dtype=torch.float64)
# Iter 385; theta =  tensor([-1.1605844486, -0.3520203421,  0.8219582433], dtype=torch.float64)
# Iter 386; theta =  tensor([-1.1607402876, -0.3527428157,  0.8220992333], dtype=torch.float64)
# Iter 387; theta =  tensor([-1.1608070487, -0.3531027482,  0.8222712320], dtype=torch.float64)
# Iter 388; theta =  tensor([-1.1609462194, -0.3538086068,  0.8224099708], dtype=torch.float64)
# Iter 389; theta =  tensor([-1.1610851505, -0.3545332491,  0.8225597691], dtype=torch.float64)
# Iter 390; theta =  tensor([-1.1612227403, -0.3551729515,  0.8227069018], dtype=torch.float64)
# Iter 391; theta =  tensor([-1.1613584492, -0.3558178950,  0.8229064070], dtype=torch.float64)
# Iter 392; theta =  tensor([-1.1614348090, -0.3562240845,  0.8230641471], dtype=torch.float64)
# Iter 393; theta =  tensor([-1.1615742770, -0.3568717124,  0.8231969462], dtype=torch.float64)
# Iter 394; theta =  tensor([-1.1617239194, -0.3576116546,  0.8233118671], dtype=torch.float64)
# Iter 395; theta =  tensor([-1.1618476352, -0.3581942640,  0.8233832556], dtype=torch.float64)
# Iter 396; theta =  tensor([-1.1619397357, -0.3586461694,  0.8235286120], dtype=torch.float64)
# Iter 397; theta =  tensor([-1.1621183551, -0.3595203275,  0.8236041121], dtype=torch.float64)
# Iter 398; theta =  tensor([-1.1621903630, -0.3599000218,  0.8237398698], dtype=torch.float64)
# Iter 399; theta =  tensor([-1.1623476597, -0.3606362960,  0.8238150191], dtype=torch.float64)
# Iter 400; theta =  tensor([-1.1625083424, -0.3613512432,  0.8239369768], dtype=torch.float64)
# Iter 401; theta =  tensor([-1.1625733113, -0.3617427487,  0.8240833119], dtype=torch.float64)
# Iter 402; theta =  tensor([-1.1626597418, -0.3621747470,  0.8242419991], dtype=torch.float64)
# Iter 403; theta =  tensor([-1.1627737106, -0.3626951669,  0.8243517117], dtype=torch.float64)
# Iter 404; theta =  tensor([-1.1628639219, -0.3631821571,  0.8245004417], dtype=torch.float64)
# Iter 405; theta =  tensor([-1.1630103305, -0.3639595783,  0.8246208676], dtype=torch.float64)
# Iter 406; theta =  tensor([-1.1631703092, -0.3647215893,  0.8247599090], dtype=torch.float64)
# Iter 407; theta =  tensor([-1.1632441523, -0.3651442463,  0.8249208675], dtype=torch.float64)
# Iter 408; theta =  tensor([-1.1634291849, -0.3659631751,  0.8250050999], dtype=torch.float64)
# Iter 409; theta =  tensor([-1.1635585932, -0.3665815859,  0.8250880889], dtype=torch.float64)
# Iter 410; theta =  tensor([-1.1636769247, -0.3672148127,  0.8251939228], dtype=torch.float64)
# Iter 411; theta =  tensor([-1.1637485001, -0.3676315188,  0.8253653178], dtype=torch.float64)
# Iter 412; theta =  tensor([-1.1638631143, -0.3681745946,  0.8254834523], dtype=torch.float64)
# Iter 413; theta =  tensor([-1.1640005862, -0.3688638346,  0.8256271443], dtype=torch.float64)
# Iter 414; theta =  tensor([-1.1641480956, -0.3695918130,  0.8257082527], dtype=torch.float64)
# Iter 415; theta =  tensor([-1.1642717558, -0.3702123073,  0.8258066614], dtype=torch.float64)
# Iter 416; theta =  tensor([-1.1643736263, -0.3707607918,  0.8259364217], dtype=torch.float64)
# Iter 417; theta =  tensor([-1.1644863074, -0.3713150291,  0.8260283370], dtype=torch.float64)
# Iter 418; theta =  tensor([-1.1645637581, -0.3717175491,  0.8261494995], dtype=torch.float64)
# Iter 419; theta =  tensor([-1.1647205417, -0.3724488257,  0.8262174762], dtype=torch.float64)
# Iter 420; theta =  tensor([-1.1648574789, -0.3730783145,  0.8262733440], dtype=torch.float64)
# Iter 421; theta =  tensor([-1.1649594564, -0.3735692162,  0.8264025332], dtype=torch.float64)
# Iter 422; theta =  tensor([-1.1650419915, -0.3740063476,  0.8265271695], dtype=torch.float64)
# Iter 423; theta =  tensor([-1.1651674159, -0.3745768636,  0.8266418817], dtype=torch.float64)
# Iter 424; theta =  tensor([-1.1652489128, -0.3750320821,  0.8267918892], dtype=torch.float64)
# Iter 425; theta =  tensor([-1.1653465391, -0.3755389546,  0.8269041278], dtype=torch.float64)
# Iter 426; theta =  tensor([-1.1655364953, -0.3763805858,  0.8269344234], dtype=torch.float64)
# Iter 427; theta =  tensor([-1.1656161692, -0.3768116634,  0.8270668329], dtype=torch.float64)
# Iter 428; theta =  tensor([-1.1657401903, -0.3774146463,  0.8271827802], dtype=torch.float64)
# Iter 429; theta =  tensor([-1.1658956842, -0.3781460716,  0.8272698804], dtype=torch.float64)
# Iter 430; theta =  tensor([-1.1660565806, -0.3787990849,  0.8273333974], dtype=torch.float64)
# Iter 431; theta =  tensor([-1.1661241017, -0.3792102188,  0.8274422857], dtype=torch.float64)
# Iter 432; theta =  tensor([-1.1662488186, -0.3798366562,  0.8275636993], dtype=torch.float64)
# Iter 433; theta =  tensor([-1.1663932172, -0.3804850126,  0.8276485145], dtype=torch.float64)

# %%
y_p = logistica_prever(Xn, theta)
print(y == y_p.int().double())
print((y == y_p.int().double()).double().mean())
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True])
# tensor(1., dtype=torch.float64)
